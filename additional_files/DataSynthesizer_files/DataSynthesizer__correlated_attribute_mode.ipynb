# %% [markdown]
# # DataSynthesizer Usage (correlated attribute mode)
#
# > This is a quick demo to use DataSynthesizer in correlated attribute mode.
#
# ### Step 1 import packages

# %%
from DataSynthesizer.DataDescriber import DataDescriber
from DataSynthesizer.DataGenerator import DataGenerator
from DataSynthesizer.ModelInspector import ModelInspector
from DataSynthesizer.lib.utils import read_json_file, display_bayesian_network

import pandas as pd
import os
import timeit

# %% [markdown]
# ### Step 2 user-defined parameteres

# %%
# input dataset
input_data = './data/adult.csv'
# location of two output files
mode = 'correlated_attribute_mode'
description_file = f'./out/{mode}/description.json'
description_file_fair = f'./out/{mode}/description_fair.json'
synthetic_data = f'./out/{mode}/sythetic_data.csv'
sythetic_data_fair= f'./out/{mode}/sythetic_data_fair.csv'

#randseed = int.from_bytes(os.urandom(4), 'big')
#randseed = 0

# %%
# An attribute is categorical if its domain size is less than this threshold.
# Here modify the threshold to adapt to the domain size of "education" (which is 14 in input dataset).
threshold_value = 30

# specify categorical attributes
categorical_attributes = {}

# specify which attributes are candidate keys of input dataset.
candidate_keys = {}

# A parameter in Differential Privacy. It roughly means that removing a row in the input dataset will not 
# change the probability of getting the same output more than a multiplicative difference of exp(epsilon).
# Increase epsilon value to reduce the injected noises. Set epsilon=0 to turn off differential privacy.
epsilon = 10

# The maximum number of parents in Bayesian network, i.e., the maximum number of incoming edges.
degree_of_bayesian_network = 0

# Number of tuples generated in synthetic dataset.
num_tuples_to_generate = 48843 # Here 32561 is the same as input dataset, but it can be set to another number.

sensitive_attributes = {"admissible": ['workclass','fnlwgt','education-num','occupation','capital-gain','capital-loss','hours-per-week'], "inadmissible": ['race','sex','native-country'], "outcome":['income>50K']}

# %% [markdown]
# ### Step 3 DataDescriber
#
# 1. Instantiate a DataDescriber.
# 2. Compute the statistics of the dataset.
# 3. Save dataset description to a file on local machine.

# %%
randseed = int.from_bytes(os.urandom(4), 'big')
describer = DataDescriber(category_threshold=threshold_value)
describer_fair = DataDescriber(category_threshold=threshold_value)

describer.describe_dataset_in_correlated_attribute_mode(dataset_file=input_data, 
                                                        epsilon=epsilon, 
                                                        k=degree_of_bayesian_network,
                                                        attribute_to_is_categorical=categorical_attributes,
                                                        attribute_to_is_candidate_key=candidate_keys,
                                                       seed = randseed)
describer.save_dataset_description_to_file(description_file)

describer_fair.describe_dataset_in_fair_correlated_attribute_mode(dataset_file=input_data, 
                                                        epsilon=epsilon, 
                                                        k=degree_of_bayesian_network,
                                                        attribute_to_is_categorical=categorical_attributes,
                                                        attribute_to_is_candidate_key=candidate_keys,
                                                        attribute_to_sensitive = sensitive_attributes,
                                                        seed = randseed)
describer_fair.save_dataset_description_to_file(description_file_fair)

# %%
print("Privbayes")
display_bayesian_network(describer.bayesian_network)
print("FairPrivbayes")
display_bayesian_network(describer_fair.bayesian_network)

# %% [markdown]
# ### Step 4 generate synthetic dataset
#
# 1. Instantiate a DataGenerator.
# 2. Generate a synthetic dataset.
# 3. Save it to local machine.

# %%
synthpath = f'./out/{mode}/Bayes_original/sythetic_data.csv'
fairsynthpath = f'./out/{mode}/Bayes_fair/sythetic_data.csv'
generator = DataGenerator()
generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file)
generator.save_synthetic_data(synthpath)

generator = DataGenerator()
generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file_fair)
generator.save_synthetic_data(fairsynthpath)

# %% [markdown]
# ## Run experiments

# %%
for i in range(10):
    randseed = int.from_bytes(os.urandom(4), 'big')
    describer = DataDescriber(category_threshold=threshold_value)
    describer_fair = DataDescriber(category_threshold=threshold_value)

    describer.describe_dataset_in_correlated_attribute_mode(dataset_file=input_data, 
                                                            epsilon=epsilon, 
                                                            k=degree_of_bayesian_network,
                                                            attribute_to_is_categorical=categorical_attributes,
                                                            attribute_to_is_candidate_key=candidate_keys,
                                                           seed = randseed)
    describer.save_dataset_description_to_file(description_file)

    describer_fair.describe_dataset_in_fair_correlated_attribute_mode(dataset_file=input_data, 
                                                            epsilon=epsilon, 
                                                            k=degree_of_bayesian_network,
                                                            attribute_to_is_categorical=categorical_attributes,
                                                            attribute_to_is_candidate_key=candidate_keys,
                                                            attribute_to_sensitive = sensitive_attributes,
                                                            seed = randseed)
    describer_fair.save_dataset_description_to_file(description_file_fair)
    
    
    print("Privbayes")
    display_bayesian_network(describer.bayesian_network)
    print("FairPrivbayes")
    display_bayesian_network(describer_fair.bayesian_network)
    
    synthpath = f'./out/{mode}/Bayes_original/sythetic_data_{i}.csv'
    fairsynthpath = f'./out/{mode}/Bayes_fair/sythetic_data_{i}.csv'
    generator = DataGenerator()
    generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file)
    generator.save_synthetic_data(synthpath)

    generator = DataGenerator()
    generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file_fair)
    generator.save_synthetic_data(fairsynthpath)


    synthpath = f'./out/{mode}/Bayes_original/sythetic_data_{i}.csv'
    fairsynthpath = f'./out/{mode}/Bayes_fair/sythetic_data_{i}.csv'
    generator = DataGenerator()
    generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file)
    generator.save_synthetic_data(synthpath)

    generator = DataGenerator()
    generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file_fair)
    generator.save_synthetic_data(fairsynthpath)

# %%
eps = [1000,100, 10 ,1 , 0.1]

for e in eps:
    for i in range(10):
        randseed = int.from_bytes(os.urandom(4), 'big')
        describer = DataDescriber(category_threshold=threshold_value)
        describer_fair = DataDescriber(category_threshold=threshold_value)

        describer.describe_dataset_in_correlated_attribute_mode(dataset_file=input_data, 
                                                                epsilon=e, 
                                                                k=degree_of_bayesian_network,
                                                                attribute_to_is_categorical=categorical_attributes,
                                                                attribute_to_is_candidate_key=candidate_keys,
                                                               seed = randseed)
        describer.save_dataset_description_to_file(description_file)

        describer_fair.describe_dataset_in_fair_correlated_attribute_mode(dataset_file=input_data, 
                                                                epsilon=e, 
                                                                k=degree_of_bayesian_network,
                                                                attribute_to_is_categorical=categorical_attributes,
                                                                attribute_to_is_candidate_key=candidate_keys,
                                                                attribute_to_sensitive = sensitive_attributes,
                                                                seed = randseed)
        describer_fair.save_dataset_description_to_file(description_file_fair)


        print("Privbayes")
        display_bayesian_network(describer.bayesian_network)
        print("FairPrivbayes")
        display_bayesian_network(describer_fair.bayesian_network)

        synthpath = f'./out/{mode}/Bayes_original/eps={e}/sythetic_data_{i}.csv'
        fairsynthpath = f'./out/{mode}/Bayes_fair/eps={e}/sythetic_data_{i}.csv'
        generator = DataGenerator()
        generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file)
        generator.save_synthetic_data(synthpath)

        generator = DataGenerator()
        generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file_fair)
        generator.save_synthetic_data(fairsynthpath)
# Out:
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT race
# Adding attribute education-num
# Adding attribute marital-status
# Adding attribute occupation
# Adding attribute workclass
# Adding attribute fnlwgt
# Adding attribute capital-gain
# Adding attribute hours-per-week
# Adding attribute relationship
# Adding attribute sex
# Adding attribute capital-loss
# Adding attribute native-country
# Adding attribute age
# Adding attribute income>50K
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT race
# Adding attribute education-num
# Adding attribute marital-status
# Adding attribute workclass
# Adding attribute capital-gain
# Adding attribute fnlwgt
# Adding attribute hours-per-week
# Adding attribute relationship
# Adding attribute sex
# Adding attribute native-country
# Adding attribute age
# Adding attribute capital-loss
# Adding attribute occupation
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     education-num  has parents ['race'].
#     marital-status has parents ['education-num', 'race'].
#     occupation     has parents ['education-num', 'marital-status', 'race'].
#     workclass      has parents ['marital-status', 'occupation', 'education-num'].
#     fnlwgt         has parents ['marital-status', 'occupation', 'race'].
#     capital-gain   has parents ['education-num', 'fnlwgt', 'race'].
#     hours-per-week has parents ['marital-status', 'capital-gain', 'education-num'].
#     relationship   has parents ['fnlwgt', 'capital-gain', 'marital-status'].
#     sex            has parents ['occupation', 'capital-gain', 'marital-status'].
#     capital-loss   has parents ['hours-per-week', 'sex', 'occupation'].
#     native-country has parents ['occupation', 'sex', 'education-num'].
#     age            has parents ['hours-per-week', 'capital-loss', 'race'].
#     income>50K     has parents ['hours-per-week', 'relationship', 'marital-status'].
# FairPrivbayes
# Constructed Bayesian network:
#     education-num  has parents ['race'].
#     marital-status has parents ['education-num', 'race'].
#     workclass      has parents ['education-num', 'marital-status', 'race'].
#     capital-gain   has parents ['education-num', 'workclass', 'race'].
#     fnlwgt         has parents ['education-num', 'capital-gain', 'race'].
#     hours-per-week has parents ['marital-status', 'workclass', 'education-num'].
#     relationship   has parents ['capital-gain', 'hours-per-week', 'race'].
#     sex            has parents ['fnlwgt', 'hours-per-week', 'race'].
#     native-country has parents ['education-num', 'fnlwgt', 'race'].
#     age            has parents ['hours-per-week', 'relationship', 'marital-status'].
#     capital-loss   has parents ['workclass', 'relationship', 'marital-status'].
#     occupation     has parents ['relationship', 'capital-loss', 'race'].
#     income>50K     has parents ['education-num', 'capital-loss', 'workclass'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT marital-status
# Adding attribute native-country
# Adding attribute age
# Adding attribute education-num
# Adding attribute income>50K
# Adding attribute hours-per-week
# Adding attribute sex
# Adding attribute capital-loss
# Adding attribute relationship
# Adding attribute occupation
# Adding attribute workclass
# Adding attribute capital-gain
# Adding attribute race
# Adding attribute fnlwgt
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT marital-status
# Adding attribute native-country
# Adding attribute age
# Adding attribute fnlwgt
# Adding attribute hours-per-week
# Adding attribute relationship
# Adding attribute race
# Adding attribute education-num
# Adding attribute occupation
# Adding attribute capital-gain
# Adding attribute capital-loss
# Adding attribute sex
# Adding attribute workclass
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     native-country has parents ['marital-status'].
#     age            has parents ['native-country', 'marital-status'].
#     education-num  has parents ['native-country', 'age', 'marital-status'].
#     income>50K     has parents ['native-country', 'age', 'marital-status'].
#     hours-per-week has parents ['native-country', 'age', 'marital-status'].
#     sex            has parents ['native-country', 'age', 'marital-status'].
#     capital-loss   has parents ['hours-per-week', 'sex', 'marital-status'].
#     relationship   has parents ['hours-per-week', 'capital-loss', 'marital-status'].
#     occupation     has parents ['education-num', 'hours-per-week', 'marital-status'].
#     workclass      has parents ['sex', 'capital-loss', 'age'].
#     capital-gain   has parents ['sex', 'capital-loss', 'native-country'].
#     race           has parents ['education-num', 'occupation', 'age'].
#     fnlwgt         has parents ['capital-loss', 'occupation', 'age'].
# FairPrivbayes
# Constructed Bayesian network:
#     native-country has parents ['marital-status'].
#     age            has parents ['native-country', 'marital-status'].
#     fnlwgt         has parents ['native-country', 'age', 'marital-status'].
#     hours-per-week has parents ['native-country', 'fnlwgt', 'marital-status'].
#     relationship   has parents ['native-country', 'age', 'marital-status'].
#     race           has parents ['hours-per-week', 'relationship', 'native-country'].
#     education-num  has parents ['hours-per-week', 'race', 'age'].
#     occupation     has parents ['native-country', 'age', 'marital-status'].
#     capital-gain   has parents ['hours-per-week', 'relationship', 'fnlwgt'].
#     capital-loss   has parents ['fnlwgt', 'education-num', 'marital-status'].
#     sex            has parents ['occupation', 'capital-loss', 'hours-per-week'].
#     workclass      has parents ['age', 'education-num', 'marital-status'].
#     income>50K     has parents ['occupation', 'hours-per-week', 'workclass'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT hours-per-week
# Adding attribute capital-gain
# Adding attribute capital-loss
# Adding attribute marital-status
# Adding attribute relationship
# Adding attribute workclass
# Adding attribute fnlwgt
# Adding attribute occupation
# Adding attribute income>50K
# Adding attribute native-country
# Adding attribute sex
# Adding attribute age
# Adding attribute race
# Adding attribute education-num
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT hours-per-week
# Adding attribute race
# Adding attribute native-country
# Adding attribute marital-status
# Adding attribute workclass
# Adding attribute capital-gain
# Adding attribute education-num
# Adding attribute capital-loss
# Adding attribute relationship
# Adding attribute age
# Adding attribute fnlwgt
# Adding attribute sex
# Adding attribute occupation
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     capital-gain   has parents ['hours-per-week'].
#     capital-loss   has parents ['capital-gain', 'hours-per-week'].
#     marital-status has parents ['capital-gain', 'capital-loss', 'hours-per-week'].
#     relationship   has parents ['capital-loss', 'marital-status', 'capital-gain'].
#     workclass      has parents ['capital-gain', 'capital-loss', 'hours-per-week'].
#     fnlwgt         has parents ['capital-loss', 'relationship', 'hours-per-week'].
#     occupation     has parents ['capital-gain', 'capital-loss', 'hours-per-week'].
#     income>50K     has parents ['fnlwgt', 'occupation', 'workclass'].
#     native-country has parents ['workclass', 'occupation', 'relationship'].
#     sex            has parents ['workclass', 'income>50K', 'relationship'].
#     age            has parents ['relationship', 'sex', 'marital-status'].
#     race           has parents ['sex', 'age', 'native-country'].
#     education-num  has parents ['sex', 'race', 'fnlwgt'].
# FairPrivbayes
# Constructed Bayesian network:
#     race           has parents ['hours-per-week'].
#     native-country has parents ['race', 'hours-per-week'].
#     marital-status has parents ['race', 'native-country', 'hours-per-week'].
#     workclass      has parents ['native-country', 'marital-status', 'race'].
#     capital-gain   has parents ['race', 'marital-status', 'hours-per-week'].
#     education-num  has parents ['marital-status', 'workclass', 'native-country'].
#     capital-loss   has parents ['native-country', 'education-num', 'race'].
#     relationship   has parents ['workclass', 'capital-loss', 'marital-status'].
#     age            has parents ['capital-gain', 'capital-loss', 'workclass'].
#     fnlwgt         has parents ['marital-status', 'workclass', 'hours-per-week'].
#     sex            has parents ['workclass', 'fnlwgt', 'race'].
#     occupation     has parents ['education-num', 'fnlwgt', 'workclass'].
#     income>50K     has parents ['capital-gain', 'capital-loss', 'education-num'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT relationship
# Adding attribute income>50K
# Adding attribute education-num
# Adding attribute capital-loss
# Adding attribute marital-status
# Adding attribute sex
# Adding attribute fnlwgt
# Adding attribute capital-gain
# Adding attribute native-country
# Adding attribute workclass
# Adding attribute occupation
# Adding attribute race
# Adding attribute hours-per-week
# Adding attribute age
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT relationship
# Adding attribute native-country
# Adding attribute education-num
# Adding attribute capital-loss
# Adding attribute marital-status
# Adding attribute hours-per-week
# Adding attribute fnlwgt
# Adding attribute workclass
# Adding attribute occupation
# Adding attribute sex
# Adding attribute race
# Adding attribute capital-gain
# Adding attribute age
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     income>50K     has parents ['relationship'].
#     education-num  has parents ['income>50K', 'relationship'].
#     capital-loss   has parents ['income>50K', 'education-num', 'relationship'].
#     marital-status has parents ['education-num', 'capital-loss', 'income>50K'].
#     sex            has parents ['education-num', 'capital-loss', 'relationship'].
#     fnlwgt         has parents ['education-num', 'marital-status', 'relationship'].
#     capital-gain   has parents ['capital-loss', 'marital-status', 'income>50K'].
#     native-country has parents ['marital-status', 'sex', 'relationship'].
#     workclass      has parents ['capital-loss', 'sex', 'income>50K'].
#     occupation     has parents ['sex', 'workclass', 'capital-loss'].
#     race           has parents ['income>50K', 'capital-gain', 'relationship'].
#     hours-per-week has parents ['capital-gain', 'race', 'capital-loss'].
#     age            has parents ['fnlwgt', 'race', 'income>50K'].
# FairPrivbayes
# Constructed Bayesian network:
#     native-country has parents ['relationship'].
#     education-num  has parents ['native-country', 'relationship'].
#     capital-loss   has parents ['native-country', 'education-num', 'relationship'].
#     marital-status has parents ['education-num', 'capital-loss', 'relationship'].
#     hours-per-week has parents ['education-num', 'marital-status', 'native-country'].
#     fnlwgt         has parents ['education-num', 'marital-status', 'relationship'].
#     workclass      has parents ['capital-loss', 'hours-per-week', 'relationship'].
#     occupation     has parents ['marital-status', 'hours-per-week', 'capital-loss'].
#     sex            has parents ['hours-per-week', 'fnlwgt', 'relationship'].
#     race           has parents ['capital-loss', 'occupation', 'education-num'].
#     capital-gain   has parents ['hours-per-week', 'fnlwgt', 'education-num'].
#     age            has parents ['occupation', 'race', 'native-country'].
#     income>50K     has parents ['fnlwgt', 'hours-per-week', 'workclass'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute marital-status
# Adding attribute occupation
# Adding attribute education-num
# Adding attribute hours-per-week
# Adding attribute fnlwgt
# Adding attribute relationship
# Adding attribute race
# Adding attribute native-country
# Adding attribute income>50K
# Adding attribute capital-gain
# Adding attribute workclass
# Adding attribute age
# Adding attribute capital-loss
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute education-num
# Adding attribute relationship
# Adding attribute age
# Adding attribute capital-loss
# Adding attribute fnlwgt
# Adding attribute marital-status
# Adding attribute race
# Adding attribute hours-per-week
# Adding attribute capital-gain
# Adding attribute native-country
# Adding attribute occupation
# Adding attribute workclass
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     marital-status has parents ['sex'].
#     occupation     has parents ['marital-status', 'sex'].
#     education-num  has parents ['marital-status', 'occupation', 'sex'].
#     hours-per-week has parents ['marital-status', 'occupation', 'sex'].
#     fnlwgt         has parents ['occupation', 'hours-per-week', 'marital-status'].
#     relationship   has parents ['occupation', 'education-num', 'marital-status'].
#     race           has parents ['occupation', 'hours-per-week', 'sex'].
#     native-country has parents ['occupation', 'hours-per-week', 'marital-status'].
#     income>50K     has parents ['race', 'native-country', 'fnlwgt'].
#     capital-gain   has parents ['education-num', 'income>50K', 'marital-status'].
#     workclass      has parents ['fnlwgt', 'race', 'education-num'].
#     age            has parents ['native-country', 'workclass', 'hours-per-week'].
#     capital-loss   has parents ['occupation', 'income>50K', 'sex'].
# FairPrivbayes
# Constructed Bayesian network:
#     education-num  has parents ['sex'].
#     relationship   has parents ['education-num', 'sex'].
#     age            has parents ['education-num', 'relationship', 'sex'].
#     capital-loss   has parents ['relationship', 'age', 'sex'].
#     fnlwgt         has parents ['age', 'capital-loss', 'sex'].
#     marital-status has parents ['age', 'fnlwgt', 'education-num'].
#     race           has parents ['age', 'fnlwgt', 'relationship'].
#     hours-per-week has parents ['fnlwgt', 'race', 'education-num'].
#     capital-gain   has parents ['fnlwgt', 'hours-per-week', 'capital-loss'].
#     native-country has parents ['hours-per-week', 'capital-gain', 'age'].
#     occupation     has parents ['fnlwgt', 'marital-status', 'capital-loss'].
#     workclass      has parents ['education-num', 'fnlwgt', 'sex'].
#     income>50K     has parents ['occupation', 'capital-gain', 'education-num'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute relationship
# Adding attribute workclass
# Adding attribute race
# Adding attribute income>50K
# Adding attribute hours-per-week
# Adding attribute native-country
# Adding attribute occupation
# Adding attribute capital-loss
# Adding attribute capital-gain
# Adding attribute fnlwgt
# Adding attribute age
# Adding attribute education-num
# Adding attribute marital-status
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute race
# Adding attribute age
# Adding attribute relationship
# Adding attribute occupation
# Adding attribute hours-per-week
# Adding attribute capital-loss
# Adding attribute marital-status
# Adding attribute native-country
# Adding attribute capital-gain
# Adding attribute workclass
# Adding attribute fnlwgt
# Adding attribute education-num
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     relationship   has parents ['sex'].
#     workclass      has parents ['relationship', 'sex'].
#     race           has parents ['relationship', 'workclass', 'sex'].
#     income>50K     has parents ['relationship', 'race', 'sex'].
#     hours-per-week has parents ['workclass', 'income>50K', 'sex'].
#     native-country has parents ['workclass', 'income>50K', 'sex'].
#     occupation     has parents ['income>50K', 'hours-per-week', 'race'].
#     capital-loss   has parents ['income>50K', 'native-country', 'race'].
#     capital-gain   has parents ['native-country', 'occupation', 'race'].
#     fnlwgt         has parents ['occupation', 'capital-gain', 'income>50K'].
#     age            has parents ['income>50K', 'occupation', 'sex'].
#     education-num  has parents ['income>50K', 'fnlwgt', 'race'].
#     marital-status has parents ['capital-gain', 'fnlwgt', 'workclass'].
# FairPrivbayes
# Constructed Bayesian network:
#     race           has parents ['sex'].
#     age            has parents ['race', 'sex'].
#     relationship   has parents ['race', 'age', 'sex'].
#     occupation     has parents ['race', 'relationship', 'sex'].
#     hours-per-week has parents ['race', 'relationship', 'sex'].
#     capital-loss   has parents ['race', 'hours-per-week', 'sex'].
#     marital-status has parents ['race', 'relationship', 'sex'].
#     native-country has parents ['age', 'capital-loss', 'sex'].
#     capital-gain   has parents ['occupation', 'capital-loss', 'relationship'].
#     workclass      has parents ['occupation', 'capital-loss', 'relationship'].
#     fnlwgt         has parents ['relationship', 'capital-gain', 'age'].
#     education-num  has parents ['occupation', 'fnlwgt', 'age'].
#     income>50K     has parents ['occupation', 'capital-loss', 'fnlwgt'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT income>50K
# Adding attribute sex
# Adding attribute capital-loss
# Adding attribute hours-per-week
# Adding attribute marital-status
# Adding attribute occupation
# Adding attribute workclass
# Adding attribute relationship
# Adding attribute age
# Adding attribute native-country
# Adding attribute education-num
# Adding attribute fnlwgt
# Adding attribute race
# Adding attribute capital-gain
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT native-country
# Adding attribute sex
# Adding attribute occupation
# Adding attribute race
# Adding attribute fnlwgt
# Adding attribute workclass
# Adding attribute age
# Adding attribute marital-status
# Adding attribute capital-gain
# Adding attribute education-num
# Adding attribute capital-loss
# Adding attribute relationship
# Adding attribute hours-per-week
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     sex            has parents ['income>50K'].
#     capital-loss   has parents ['sex', 'income>50K'].
#     hours-per-week has parents ['sex', 'capital-loss', 'income>50K'].
#     marital-status has parents ['sex', 'hours-per-week', 'income>50K'].
#     occupation     has parents ['sex', 'hours-per-week', 'income>50K'].
#     workclass      has parents ['hours-per-week', 'occupation', 'sex'].
#     relationship   has parents ['marital-status', 'workclass', 'hours-per-week'].
#     age            has parents ['occupation', 'relationship', 'income>50K'].
#     native-country has parents ['occupation', 'workclass', 'hours-per-week'].
#     education-num  has parents ['workclass', 'native-country', 'marital-status'].
#     fnlwgt         has parents ['marital-status', 'relationship', 'capital-loss'].
#     race           has parents ['age', 'native-country', 'income>50K'].
#     capital-gain   has parents ['occupation', 'native-country', 'capital-loss'].
# FairPrivbayes
# Constructed Bayesian network:
#     sex            has parents ['native-country'].
#     occupation     has parents ['sex', 'native-country'].
#     race           has parents ['sex', 'occupation', 'native-country'].
#     fnlwgt         has parents ['sex', 'occupation', 'native-country'].
#     workclass      has parents ['occupation', 'fnlwgt', 'sex'].
#     age            has parents ['sex', 'fnlwgt', 'native-country'].
#     marital-status has parents ['fnlwgt', 'workclass', 'sex'].
#     capital-gain   has parents ['fnlwgt', 'workclass', 'race'].
#     education-num  has parents ['race', 'fnlwgt', 'native-country'].
#     capital-loss   has parents ['marital-status', 'education-num', 'workclass'].
#     relationship   has parents ['marital-status', 'capital-loss', 'age'].
#     hours-per-week has parents ['capital-loss', 'relationship', 'occupation'].
#     income>50K     has parents ['education-num', 'hours-per-week', 'workclass'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT occupation
# Adding attribute capital-gain
# Adding attribute relationship
# Adding attribute capital-loss
# Adding attribute education-num
# Adding attribute hours-per-week
# Adding attribute race
# Adding attribute income>50K
# Adding attribute workclass
# Adding attribute fnlwgt
# Adding attribute marital-status
# Adding attribute native-country
# Adding attribute age
# Adding attribute sex
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT occupation
# Adding attribute capital-gain
# Adding attribute relationship
# Adding attribute sex
# Adding attribute hours-per-week
# Adding attribute race
# Adding attribute capital-loss
# Adding attribute workclass
# Adding attribute age
# Adding attribute marital-status
# Adding attribute fnlwgt
# Adding attribute native-country
# Adding attribute education-num
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     capital-gain   has parents ['occupation'].
#     relationship   has parents ['capital-gain', 'occupation'].
#     capital-loss   has parents ['capital-gain', 'relationship', 'occupation'].
#     education-num  has parents ['capital-gain', 'relationship', 'occupation'].
#     hours-per-week has parents ['capital-loss', 'education-num', 'capital-gain'].
#     race           has parents ['capital-loss', 'hours-per-week', 'occupation'].
#     income>50K     has parents ['hours-per-week', 'race', 'education-num'].
#     workclass      has parents ['capital-loss', 'race', 'relationship'].
#     fnlwgt         has parents ['income>50K', 'workclass', 'occupation'].
#     marital-status has parents ['race', 'income>50K', 'relationship'].
#     native-country has parents ['workclass', 'marital-status', 'education-num'].
#     age            has parents ['hours-per-week', 'income>50K', 'education-num'].
#     sex            has parents ['workclass', 'age', 'income>50K'].
# FairPrivbayes
# Constructed Bayesian network:
#     capital-gain   has parents ['occupation'].
#     relationship   has parents ['capital-gain', 'occupation'].
#     sex            has parents ['capital-gain', 'relationship', 'occupation'].
#     hours-per-week has parents ['relationship', 'sex', 'capital-gain'].
#     race           has parents ['relationship', 'hours-per-week', 'occupation'].
#     capital-loss   has parents ['relationship', 'race', 'occupation'].
#     workclass      has parents ['hours-per-week', 'capital-loss', 'sex'].
#     age            has parents ['capital-gain', 'hours-per-week', 'occupation'].
#     marital-status has parents ['sex', 'race', 'occupation'].
#     fnlwgt         has parents ['workclass', 'marital-status', 'capital-gain'].
#     native-country has parents ['workclass', 'age', 'occupation'].
#     education-num  has parents ['workclass', 'native-country', 'capital-loss'].
#     income>50K     has parents ['capital-loss', 'hours-per-week', 'education-num'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute hours-per-week
# Adding attribute fnlwgt
# Adding attribute education-num
# Adding attribute relationship
# Adding attribute occupation
# Adding attribute marital-status
# Adding attribute workclass
# Adding attribute income>50K
# Adding attribute age
# Adding attribute native-country
# Adding attribute race
# Adding attribute capital-gain
# Adding attribute capital-loss
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute hours-per-week
# Adding attribute education-num
# Adding attribute workclass
# Adding attribute relationship
# Adding attribute capital-gain
# Adding attribute occupation
# Adding attribute age
# Adding attribute capital-loss
# Adding attribute native-country
# Adding attribute marital-status
# Adding attribute fnlwgt
# Adding attribute race
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     hours-per-week has parents ['sex'].
#     fnlwgt         has parents ['hours-per-week', 'sex'].
#     education-num  has parents ['hours-per-week', 'fnlwgt', 'sex'].
#     relationship   has parents ['fnlwgt', 'education-num', 'hours-per-week'].
#     occupation     has parents ['hours-per-week', 'education-num', 'sex'].
#     marital-status has parents ['fnlwgt', 'occupation', 'hours-per-week'].
#     workclass      has parents ['hours-per-week', 'fnlwgt', 'sex'].
#     income>50K     has parents ['relationship', 'occupation', 'education-num'].
#     age            has parents ['education-num', 'occupation', 'sex'].
#     native-country has parents ['workclass', 'age', 'sex'].
#     race           has parents ['occupation', 'age', 'relationship'].
#     capital-gain   has parents ['income>50K', 'race', 'marital-status'].
#     capital-loss   has parents ['race', 'capital-gain', 'marital-status'].
# FairPrivbayes
# Constructed Bayesian network:
#     hours-per-week has parents ['sex'].
#     education-num  has parents ['hours-per-week', 'sex'].
#     workclass      has parents ['hours-per-week', 'education-num', 'sex'].
#     relationship   has parents ['education-num', 'workclass', 'sex'].
#     capital-gain   has parents ['hours-per-week', 'education-num', 'sex'].
#     occupation     has parents ['workclass', 'relationship', 'sex'].
#     age            has parents ['education-num', 'relationship', 'sex'].
#     capital-loss   has parents ['hours-per-week', 'relationship', 'sex'].
#     native-country has parents ['occupation', 'age', 'education-num'].
#     marital-status has parents ['relationship', 'native-country', 'sex'].
#     fnlwgt         has parents ['relationship', 'occupation', 'education-num'].
#     race           has parents ['relationship', 'capital-loss', 'workclass'].
#     income>50K     has parents ['education-num', 'capital-gain', 'workclass'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT income>50K
# Adding attribute native-country
# Adding attribute workclass
# Adding attribute sex
# Adding attribute capital-loss
# Adding attribute education-num
# Adding attribute capital-gain
# Adding attribute hours-per-week
# Adding attribute race
# Adding attribute fnlwgt
# Adding attribute marital-status
# Adding attribute relationship
# Adding attribute age
# Adding attribute occupation
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT capital-gain
# Adding attribute capital-loss
# Adding attribute marital-status
# Adding attribute hours-per-week
# Adding attribute fnlwgt
# Adding attribute workclass
# Adding attribute race
# Adding attribute relationship
# Adding attribute occupation
# Adding attribute native-country
# Adding attribute education-num
# Adding attribute sex
# Adding attribute age
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     native-country has parents ['income>50K'].
#     workclass      has parents ['native-country', 'income>50K'].
#     sex            has parents ['native-country', 'workclass', 'income>50K'].
#     capital-loss   has parents ['workclass', 'sex', 'income>50K'].
#     education-num  has parents ['native-country', 'capital-loss', 'income>50K'].
#     capital-gain   has parents ['workclass', 'sex', 'income>50K'].
#     hours-per-week has parents ['capital-loss', 'education-num', 'sex'].
#     race           has parents ['sex', 'capital-loss', 'income>50K'].
#     fnlwgt         has parents ['education-num', 'capital-gain', 'sex'].
#     marital-status has parents ['workclass', 'capital-loss', 'native-country'].
#     relationship   has parents ['workclass', 'capital-gain', 'income>50K'].
#     age            has parents ['workclass', 'capital-loss', 'native-country'].
#     occupation     has parents ['race', 'relationship', 'native-country'].
# FairPrivbayes
# Constructed Bayesian network:
#     capital-loss   has parents ['capital-gain'].
#     marital-status has parents ['capital-loss', 'capital-gain'].
#     hours-per-week has parents ['capital-loss', 'marital-status', 'capital-gain'].
#     fnlwgt         has parents ['capital-loss', 'marital-status', 'capital-gain'].
#     workclass      has parents ['hours-per-week', 'fnlwgt', 'capital-loss'].
#     race           has parents ['marital-status', 'workclass', 'capital-gain'].
#     relationship   has parents ['workclass', 'race', 'hours-per-week'].
#     occupation     has parents ['hours-per-week', 'race', 'capital-gain'].
#     native-country has parents ['hours-per-week', 'relationship', 'capital-loss'].
#     education-num  has parents ['race', 'native-country', 'capital-gain'].
#     sex            has parents ['race', 'native-country', 'capital-loss'].
#     age            has parents ['native-country', 'sex', 'workclass'].
#     income>50K     has parents ['occupation', 'capital-gain', 'education-num'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT relationship
# Adding attribute native-country
# Adding attribute income>50K
# Adding attribute workclass
# Adding attribute sex
# Adding attribute occupation
# Adding attribute hours-per-week
# Adding attribute fnlwgt
# Adding attribute race
# Adding attribute capital-loss
# Adding attribute marital-status
# Adding attribute education-num
# Adding attribute age
# Adding attribute capital-gain
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT relationship
# Adding attribute hours-per-week
# Adding attribute native-country
# Adding attribute age
# Adding attribute occupation
# Adding attribute sex
# Adding attribute capital-gain
# Adding attribute workclass
# Adding attribute marital-status
# Adding attribute race
# Adding attribute education-num
# Adding attribute capital-loss
# Adding attribute fnlwgt
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     native-country has parents ['relationship'].
#     income>50K     has parents ['native-country', 'relationship'].
#     workclass      has parents ['native-country', 'income>50K', 'relationship'].
#     sex            has parents ['income>50K', 'workclass', 'relationship'].
#     occupation     has parents ['workclass', 'sex', 'relationship'].
#     hours-per-week has parents ['income>50K', 'workclass', 'relationship'].
#     fnlwgt         has parents ['sex', 'occupation', 'native-country'].
#     race           has parents ['workclass', 'hours-per-week', 'relationship'].
#     capital-loss   has parents ['sex', 'race', 'workclass'].
#     marital-status has parents ['occupation', 'race', 'sex'].
#     education-num  has parents ['sex', 'marital-status', 'workclass'].
#     age            has parents ['hours-per-week', 'education-num', 'native-country'].
#     capital-gain   has parents ['fnlwgt', 'capital-loss', 'relationship'].
# FairPrivbayes
# Constructed Bayesian network:
#     hours-per-week has parents ['relationship'].
#     native-country has parents ['hours-per-week', 'relationship'].
#     age            has parents ['hours-per-week', 'native-country', 'relationship'].
#     occupation     has parents ['native-country', 'age', 'relationship'].
#     sex            has parents ['age', 'occupation', 'native-country'].
#     capital-gain   has parents ['hours-per-week', 'occupation', 'relationship'].
#     workclass      has parents ['sex', 'capital-gain', 'native-country'].
#     marital-status has parents ['sex', 'workclass', 'native-country'].
#     race           has parents ['occupation', 'workclass', 'hours-per-week'].
#     education-num  has parents ['capital-gain', 'race', 'occupation'].
#     capital-loss   has parents ['sex', 'capital-gain', 'relationship'].
#     fnlwgt         has parents ['occupation', 'marital-status', 'hours-per-week'].
#     income>50K     has parents ['capital-loss', 'hours-per-week', 'occupation'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT relationship
# Adding attribute education-num
# Adding attribute hours-per-week
# Adding attribute occupation
# Adding attribute fnlwgt
# Adding attribute capital-gain
# Adding attribute marital-status
# Adding attribute workclass
# Adding attribute income>50K
# Adding attribute race
# Adding attribute native-country
# Adding attribute age
# Adding attribute capital-loss
# Adding attribute sex
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT relationship
# Adding attribute education-num
# Adding attribute hours-per-week
# Adding attribute workclass
# Adding attribute race
# Adding attribute capital-gain
# Adding attribute fnlwgt
# Adding attribute marital-status
# Adding attribute occupation
# Adding attribute sex
# Adding attribute age
# Adding attribute native-country
# Adding attribute capital-loss
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     education-num  has parents ['relationship'].
#     hours-per-week has parents ['education-num', 'relationship'].
#     occupation     has parents ['education-num', 'hours-per-week', 'relationship'].
#     fnlwgt         has parents ['education-num', 'occupation', 'relationship'].
#     capital-gain   has parents ['hours-per-week', 'occupation', 'education-num'].
#     marital-status has parents ['fnlwgt', 'capital-gain', 'education-num'].
#     workclass      has parents ['occupation', 'capital-gain', 'relationship'].
#     income>50K     has parents ['fnlwgt', 'capital-gain', 'occupation'].
#     race           has parents ['marital-status', 'workclass', 'fnlwgt'].
#     native-country has parents ['workclass', 'race', 'marital-status'].
#     age            has parents ['fnlwgt', 'marital-status', 'hours-per-week'].
#     capital-loss   has parents ['income>50K', 'native-country', 'education-num'].
#     sex            has parents ['marital-status', 'workclass', 'hours-per-week'].
# FairPrivbayes
# Constructed Bayesian network:
#     education-num  has parents ['relationship'].
#     hours-per-week has parents ['education-num', 'relationship'].
#     workclass      has parents ['education-num', 'hours-per-week', 'relationship'].
#     race           has parents ['hours-per-week', 'workclass', 'education-num'].
#     capital-gain   has parents ['hours-per-week', 'workclass', 'education-num'].
#     fnlwgt         has parents ['hours-per-week', 'race', 'relationship'].
#     marital-status has parents ['race', 'fnlwgt', 'education-num'].
#     occupation     has parents ['education-num', 'workclass', 'relationship'].
#     sex            has parents ['race', 'occupation', 'relationship'].
#     age            has parents ['workclass', 'race', 'hours-per-week'].
#     native-country has parents ['marital-status', 'occupation', 'workclass'].
#     capital-loss   has parents ['fnlwgt', 'marital-status', 'education-num'].
#     income>50K     has parents ['occupation', 'hours-per-week', 'workclass'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT relationship
# Adding attribute sex
# Adding attribute workclass
# Adding attribute race
# Adding attribute capital-gain
# Adding attribute capital-loss
# Adding attribute native-country
# Adding attribute education-num
# Adding attribute fnlwgt
# Adding attribute hours-per-week
# Adding attribute occupation
# Adding attribute income>50K
# Adding attribute marital-status
# Adding attribute age
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT relationship
# Adding attribute sex
# Adding attribute capital-gain
# Adding attribute race
# Adding attribute marital-status
# Adding attribute native-country
# Adding attribute occupation
# Adding attribute fnlwgt
# Adding attribute workclass
# Adding attribute education-num
# Adding attribute age
# Adding attribute capital-loss
# Adding attribute hours-per-week
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     sex            has parents ['relationship'].
#     workclass      has parents ['sex', 'relationship'].
#     race           has parents ['sex', 'workclass', 'relationship'].
#     capital-gain   has parents ['sex', 'race', 'relationship'].
#     capital-loss   has parents ['race', 'capital-gain', 'sex'].
#     native-country has parents ['workclass', 'capital-loss', 'relationship'].
#     education-num  has parents ['race', 'native-country', 'sex'].
#     fnlwgt         has parents ['capital-loss', 'education-num', 'sex'].
#     hours-per-week has parents ['workclass', 'fnlwgt', 'sex'].
#     occupation     has parents ['education-num', 'fnlwgt', 'capital-gain'].
#     income>50K     has parents ['capital-gain', 'capital-loss', 'race'].
#     marital-status has parents ['fnlwgt', 'income>50K', 'capital-gain'].
#     age            has parents ['education-num', 'hours-per-week', 'race'].
# FairPrivbayes
# Constructed Bayesian network:
#     sex            has parents ['relationship'].
#     capital-gain   has parents ['sex', 'relationship'].
#     race           has parents ['sex', 'capital-gain', 'relationship'].
#     marital-status has parents ['capital-gain', 'race', 'sex'].
#     native-country has parents ['race', 'marital-status', 'capital-gain'].
#     occupation     has parents ['marital-status', 'native-country', 'sex'].
#     fnlwgt         has parents ['race', 'marital-status', 'sex'].
#     workclass      has parents ['sex', 'native-country', 'relationship'].
#     education-num  has parents ['capital-gain', 'occupation', 'relationship'].
#     age            has parents ['capital-gain', 'occupation', 'sex'].
#     capital-loss   has parents ['capital-gain', 'fnlwgt', 'sex'].
#     hours-per-week has parents ['marital-status', 'native-country', 'sex'].
#     income>50K     has parents ['capital-gain', 'capital-loss', 'workclass'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT marital-status
# Adding attribute education-num
# Adding attribute hours-per-week
# Adding attribute capital-loss
# Adding attribute capital-gain
# Adding attribute fnlwgt
# Adding attribute sex
# Adding attribute income>50K
# Adding attribute age
# Adding attribute race
# Adding attribute relationship
# Adding attribute native-country
# Adding attribute occupation
# Adding attribute workclass
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT marital-status
# Adding attribute education-num
# Adding attribute occupation
# Adding attribute age
# Adding attribute capital-gain
# Adding attribute sex
# Adding attribute capital-loss
# Adding attribute fnlwgt
# Adding attribute race
# Adding attribute hours-per-week
# Adding attribute native-country
# Adding attribute workclass
# Adding attribute relationship
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     education-num  has parents ['marital-status'].
#     hours-per-week has parents ['education-num', 'marital-status'].
#     capital-loss   has parents ['education-num', 'hours-per-week', 'marital-status'].
#     capital-gain   has parents ['hours-per-week', 'capital-loss', 'education-num'].
#     fnlwgt         has parents ['hours-per-week', 'capital-loss', 'education-num'].
#     sex            has parents ['hours-per-week', 'capital-loss', 'education-num'].
#     income>50K     has parents ['capital-gain', 'fnlwgt', 'hours-per-week'].
#     age            has parents ['capital-loss', 'capital-gain', 'marital-status'].
#     race           has parents ['income>50K', 'age', 'capital-gain'].
#     relationship   has parents ['education-num', 'age', 'marital-status'].
#     native-country has parents ['race', 'relationship', 'capital-gain'].
#     occupation     has parents ['sex', 'relationship', 'capital-gain'].
#     workclass      has parents ['age', 'occupation', 'marital-status'].
# FairPrivbayes
# Constructed Bayesian network:
#     education-num  has parents ['marital-status'].
#     occupation     has parents ['education-num', 'marital-status'].
#     age            has parents ['education-num', 'occupation', 'marital-status'].
#     capital-gain   has parents ['occupation', 'age', 'marital-status'].
#     sex            has parents ['occupation', 'age', 'marital-status'].
#     capital-loss   has parents ['occupation', 'age', 'education-num'].
#     fnlwgt         has parents ['capital-gain', 'capital-loss', 'occupation'].
#     race           has parents ['education-num', 'fnlwgt', 'marital-status'].
#     hours-per-week has parents ['occupation', 'sex', 'marital-status'].
#     native-country has parents ['capital-gain', 'race', 'age'].
#     workclass      has parents ['fnlwgt', 'native-country', 'capital-loss'].
#     relationship   has parents ['age', 'workclass', 'marital-status'].
#     income>50K     has parents ['occupation', 'hours-per-week', 'workclass'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT income>50K
# Adding attribute hours-per-week
# Adding attribute capital-gain
# Adding attribute race
# Adding attribute marital-status
# Adding attribute native-country
# Adding attribute sex
# Adding attribute occupation
# Adding attribute fnlwgt
# Adding attribute workclass
# Adding attribute capital-loss
# Adding attribute education-num
# Adding attribute age
# Adding attribute relationship
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT age
# Adding attribute native-country
# Adding attribute relationship
# Adding attribute hours-per-week
# Adding attribute capital-gain
# Adding attribute capital-loss
# Adding attribute occupation
# Adding attribute sex
# Adding attribute marital-status
# Adding attribute race
# Adding attribute workclass
# Adding attribute fnlwgt
# Adding attribute education-num
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     hours-per-week has parents ['income>50K'].
#     capital-gain   has parents ['hours-per-week', 'income>50K'].
#     race           has parents ['hours-per-week', 'capital-gain', 'income>50K'].
#     marital-status has parents ['capital-gain', 'race', 'income>50K'].
#     native-country has parents ['capital-gain', 'race', 'hours-per-week'].
#     sex            has parents ['race', 'native-country', 'capital-gain'].
#     occupation     has parents ['race', 'marital-status', 'capital-gain'].
#     fnlwgt         has parents ['sex', 'occupation', 'native-country'].
#     workclass      has parents ['marital-status', 'native-country', 'race'].
#     capital-loss   has parents ['sex', 'occupation', 'capital-gain'].
#     education-num  has parents ['occupation', 'fnlwgt', 'capital-gain'].
#     age            has parents ['race', 'fnlwgt', 'hours-per-week'].
#     relationship   has parents ['capital-loss', 'education-num', 'fnlwgt'].
# FairPrivbayes
# Constructed Bayesian network:
#     native-country has parents ['age'].
#     relationship   has parents ['native-country', 'age'].
#     hours-per-week has parents ['native-country', 'relationship', 'age'].
#     capital-gain   has parents ['relationship', 'hours-per-week', 'native-country'].
#     capital-loss   has parents ['relationship', 'hours-per-week', 'native-country'].
#     occupation     has parents ['relationship', 'hours-per-week', 'age'].
#     sex            has parents ['relationship', 'hours-per-week', 'age'].
#     marital-status has parents ['capital-gain', 'capital-loss', 'relationship'].
#     race           has parents ['relationship', 'sex', 'native-country'].
#     workclass      has parents ['capital-loss', 'sex', 'relationship'].
#     fnlwgt         has parents ['sex', 'marital-status', 'relationship'].
#     education-num  has parents ['workclass', 'fnlwgt', 'race'].
#     income>50K     has parents ['occupation', 'hours-per-week', 'fnlwgt'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT native-country
# Adding attribute income>50K
# Adding attribute marital-status
# Adding attribute relationship
# Adding attribute hours-per-week
# Adding attribute capital-gain
# Adding attribute occupation
# Adding attribute race
# Adding attribute education-num
# Adding attribute age
# Adding attribute fnlwgt
# Adding attribute sex
# Adding attribute workclass
# Adding attribute capital-loss
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT native-country
# Adding attribute sex
# Adding attribute workclass
# Adding attribute marital-status
# Adding attribute hours-per-week
# Adding attribute race
# Adding attribute fnlwgt
# Adding attribute age
# Adding attribute education-num
# Adding attribute capital-gain
# Adding attribute occupation
# Adding attribute capital-loss
# Adding attribute relationship
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     income>50K     has parents ['native-country'].
#     marital-status has parents ['income>50K', 'native-country'].
#     relationship   has parents ['income>50K', 'marital-status', 'native-country'].
#     hours-per-week has parents ['income>50K', 'relationship', 'native-country'].
#     capital-gain   has parents ['income>50K', 'hours-per-week', 'native-country'].
#     occupation     has parents ['relationship', 'capital-gain', 'marital-status'].
#     race           has parents ['relationship', 'capital-gain', 'income>50K'].
#     education-num  has parents ['capital-gain', 'race', 'relationship'].
#     age            has parents ['occupation', 'education-num', 'capital-gain'].
#     fnlwgt         has parents ['occupation', 'education-num', 'capital-gain'].
#     sex            has parents ['hours-per-week', 'capital-gain', 'relationship'].
#     workclass      has parents ['capital-gain', 'age', 'income>50K'].
#     capital-loss   has parents ['relationship', 'age', 'native-country'].
# FairPrivbayes
# Constructed Bayesian network:
#     sex            has parents ['native-country'].
#     workclass      has parents ['sex', 'native-country'].
#     marital-status has parents ['sex', 'workclass', 'native-country'].
#     hours-per-week has parents ['sex', 'marital-status', 'native-country'].
#     race           has parents ['sex', 'workclass', 'native-country'].
#     fnlwgt         has parents ['workclass', 'race', 'sex'].
#     age            has parents ['sex', 'fnlwgt', 'native-country'].
#     education-num  has parents ['marital-status', 'hours-per-week', 'sex'].
#     capital-gain   has parents ['marital-status', 'fnlwgt', 'sex'].
#     occupation     has parents ['sex', 'age', 'native-country'].
#     capital-loss   has parents ['marital-status', 'occupation', 'sex'].
#     relationship   has parents ['race', 'fnlwgt', 'native-country'].
#     income>50K     has parents ['capital-gain', 'capital-loss', 'occupation'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT workclass
# Adding attribute fnlwgt
# Adding attribute race
# ...
#     age            has parents ['workclass', 'occupation', 'capital-loss'].
#     education-num  has parents ['native-country', 'occupation', 'marital-status'].
#     relationship   has parents ['sex', 'education-num', 'capital-gain'].
#     income>50K     has parents ['native-country', 'relationship', 'hours-per-week'].
# FairPrivbayes
# Constructed Bayesian network:
#     native-country has parents ['marital-status'].
#     relationship   has parents ['native-country', 'marital-status'].
#     occupation     has parents ['native-country', 'relationship', 'marital-status'].
#     capital-loss   has parents ['relationship', 'occupation', 'native-country'].
#     fnlwgt         has parents ['relationship', 'capital-loss', 'native-country'].
#     race           has parents ['native-country', 'capital-loss', 'marital-status'].
#     age            has parents ['native-country', 'occupation', 'marital-status'].
#     workclass      has parents ['occupation', 'capital-loss', 'relationship'].
#     capital-gain   has parents ['capital-loss', 'race', 'occupation'].
#     education-num  has parents ['race', 'workclass', 'occupation'].
#     hours-per-week has parents ['native-country', 'race', 'marital-status'].
#     sex            has parents ['occupation', 'fnlwgt', 'marital-status'].
#     income>50K     has parents ['fnlwgt', 'capital-loss', 'workclass'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT education-num
# Adding attribute native-country
# Adding attribute age
# Adding attribute fnlwgt
# Adding attribute occupation
# Adding attribute relationship
# Adding attribute capital-gain
# Adding attribute capital-loss
# Adding attribute race
# Adding attribute hours-per-week
# Adding attribute marital-status
# Adding attribute sex
# Adding attribute workclass
# Adding attribute income>50K
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT education-num
# Adding attribute hours-per-week
# Adding attribute age
# Adding attribute race
# Adding attribute capital-loss
# Adding attribute native-country
# Adding attribute workclass
# Adding attribute fnlwgt
# Adding attribute relationship
# Adding attribute capital-gain
# Adding attribute marital-status
# Adding attribute sex
# Adding attribute occupation
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     native-country has parents ['education-num'].
#     age            has parents ['native-country', 'education-num'].
#     fnlwgt         has parents ['native-country', 'age', 'education-num'].
#     occupation     has parents ['native-country', 'fnlwgt', 'education-num'].
#     relationship   has parents ['native-country', 'occupation', 'education-num'].
#     capital-gain   has parents ['native-country', 'age', 'education-num'].
#     capital-loss   has parents ['native-country', 'occupation', 'education-num'].
#     race           has parents ['relationship', 'capital-loss', 'occupation'].
#     hours-per-week has parents ['fnlwgt', 'capital-gain', 'age'].
#     marital-status has parents ['native-country', 'capital-gain', 'education-num'].
#     sex            has parents ['fnlwgt', 'capital-loss', 'age'].
#     workclass      has parents ['fnlwgt', 'relationship', 'age'].
#     income>50K     has parents ['race', 'marital-status', 'fnlwgt'].
# FairPrivbayes
# Constructed Bayesian network:
#     hours-per-week has parents ['education-num'].
#     age            has parents ['hours-per-week', 'education-num'].
#     race           has parents ['hours-per-week', 'age', 'education-num'].
#     capital-loss   has parents ['hours-per-week', 'race', 'education-num'].
#     native-country has parents ['age', 'capital-loss', 'hours-per-week'].
#     workclass      has parents ['hours-per-week', 'race', 'education-num'].
#     fnlwgt         has parents ['age', 'capital-loss', 'education-num'].
#     relationship   has parents ['race', 'native-country', 'education-num'].
#     capital-gain   has parents ['race', 'capital-loss', 'education-num'].
#     marital-status has parents ['workclass', 'fnlwgt', 'age'].
#     sex            has parents ['race', 'marital-status', 'age'].
#     occupation     has parents ['capital-gain', 'marital-status', 'age'].
#     income>50K     has parents ['fnlwgt', 'capital-gain', 'workclass'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT fnlwgt
# Adding attribute capital-gain
# Adding attribute native-country
# Adding attribute marital-status
# Adding attribute occupation
# Adding attribute sex
# Adding attribute workclass
# Adding attribute age
# Adding attribute relationship
# Adding attribute capital-loss
# Adding attribute hours-per-week
# Adding attribute education-num
# Adding attribute income>50K
# Adding attribute race
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT fnlwgt
# Adding attribute marital-status
# Adding attribute native-country
# Adding attribute occupation
# Adding attribute capital-gain
# Adding attribute education-num
# Adding attribute race
# Adding attribute age
# Adding attribute hours-per-week
# Adding attribute workclass
# Adding attribute sex
# Adding attribute relationship
# Adding attribute capital-loss
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     capital-gain   has parents ['fnlwgt'].
#     native-country has parents ['capital-gain', 'fnlwgt'].
#     marital-status has parents ['capital-gain', 'native-country', 'fnlwgt'].
#     occupation     has parents ['native-country', 'marital-status', 'fnlwgt'].
#     sex            has parents ['native-country', 'occupation', 'capital-gain'].
#     workclass      has parents ['occupation', 'sex', 'native-country'].
#     age            has parents ['occupation', 'workclass', 'native-country'].
#     relationship   has parents ['marital-status', 'workclass', 'native-country'].
#     capital-loss   has parents ['age', 'relationship', 'marital-status'].
#     hours-per-week has parents ['workclass', 'relationship', 'capital-gain'].
#     education-num  has parents ['age', 'capital-loss', 'workclass'].
#     income>50K     has parents ['workclass', 'relationship', 'native-country'].
#     race           has parents ['occupation', 'education-num', 'capital-gain'].
# FairPrivbayes
# Constructed Bayesian network:
#     marital-status has parents ['fnlwgt'].
#     native-country has parents ['marital-status', 'fnlwgt'].
#     occupation     has parents ['marital-status', 'native-country', 'fnlwgt'].
#     capital-gain   has parents ['marital-status', 'occupation', 'fnlwgt'].
#     education-num  has parents ['marital-status', 'occupation', 'fnlwgt'].
#     race           has parents ['native-country', 'occupation', 'marital-status'].
#     age            has parents ['capital-gain', 'race', 'native-country'].
#     hours-per-week has parents ['occupation', 'capital-gain', 'native-country'].
#     workclass      has parents ['occupation', 'hours-per-week', 'native-country'].
#     sex            has parents ['capital-gain', 'race', 'native-country'].
#     relationship   has parents ['education-num', 'age', 'marital-status'].
#     capital-loss   has parents ['hours-per-week', 'relationship', 'race'].
#     income>50K     has parents ['occupation', 'capital-loss', 'fnlwgt'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute race
# Adding attribute capital-gain
# Adding attribute marital-status
# Adding attribute fnlwgt
# Adding attribute native-country
# Adding attribute capital-loss
# Adding attribute relationship
# Adding attribute education-num
# Adding attribute occupation
# Adding attribute age
# Adding attribute income>50K
# Adding attribute workclass
# Adding attribute hours-per-week
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute race
# Adding attribute native-country
# Adding attribute marital-status
# Adding attribute workclass
# Adding attribute hours-per-week
# Adding attribute education-num
# Adding attribute capital-loss
# Adding attribute fnlwgt
# Adding attribute age
# Adding attribute capital-gain
# Adding attribute occupation
# Adding attribute relationship
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     race           has parents ['sex'].
#     capital-gain   has parents ['race', 'sex'].
#     marital-status has parents ['race', 'capital-gain', 'sex'].
#     fnlwgt         has parents ['race', 'marital-status', 'sex'].
#     native-country has parents ['race', 'capital-gain', 'sex'].
#     capital-loss   has parents ['capital-gain', 'fnlwgt', 'sex'].
#     relationship   has parents ['fnlwgt', 'capital-loss', 'sex'].
#     education-num  has parents ['race', 'native-country', 'sex'].
#     occupation     has parents ['capital-loss', 'relationship', 'capital-gain'].
#     age            has parents ['race', 'education-num', 'sex'].
#     income>50K     has parents ['capital-gain', 'age', 'sex'].
#     workclass      has parents ['relationship', 'age', 'fnlwgt'].
#     hours-per-week has parents ['occupation', 'workclass', 'fnlwgt'].
# FairPrivbayes
# Constructed Bayesian network:
#     race           has parents ['sex'].
#     native-country has parents ['race', 'sex'].
#     marital-status has parents ['race', 'native-country', 'sex'].
#     workclass      has parents ['native-country', 'marital-status', 'race'].
#     hours-per-week has parents ['marital-status', 'workclass', 'sex'].
#     education-num  has parents ['race', 'hours-per-week', 'sex'].
#     capital-loss   has parents ['native-country', 'marital-status', 'sex'].
#     fnlwgt         has parents ['education-num', 'capital-loss', 'hours-per-week'].
#     age            has parents ['native-country', 'education-num', 'race'].
#     capital-gain   has parents ['marital-status', 'hours-per-week', 'sex'].
#     occupation     has parents ['race', 'fnlwgt', 'sex'].
#     relationship   has parents ['capital-gain', 'occupation', 'sex'].
#     income>50K     has parents ['education-num', 'capital-loss', 'workclass'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT income>50K
# Adding attribute fnlwgt
# Adding attribute workclass
# Adding attribute native-country
# Adding attribute sex
# Adding attribute race
# Adding attribute education-num
# Adding attribute hours-per-week
# Adding attribute occupation
# Adding attribute marital-status
# Adding attribute relationship
# Adding attribute capital-gain
# Adding attribute age
# Adding attribute capital-loss
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute fnlwgt
# Adding attribute workclass
# Adding attribute education-num
# Adding attribute native-country
# Adding attribute capital-loss
# Adding attribute capital-gain
# Adding attribute marital-status
# Adding attribute age
# Adding attribute race
# Adding attribute occupation
# Adding attribute hours-per-week
# Adding attribute relationship
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     fnlwgt         has parents ['income>50K'].
#     workclass      has parents ['fnlwgt', 'income>50K'].
#     native-country has parents ['fnlwgt', 'workclass', 'income>50K'].
#     sex            has parents ['workclass', 'native-country', 'fnlwgt'].
#     race           has parents ['workclass', 'sex', 'fnlwgt'].
#     education-num  has parents ['fnlwgt', 'race', 'income>50K'].
#     hours-per-week has parents ['sex', 'race', 'fnlwgt'].
#     occupation     has parents ['sex', 'race', 'native-country'].
#     marital-status has parents ['native-country', 'hours-per-week', 'fnlwgt'].
#     relationship   has parents ['occupation', 'marital-status', 'hours-per-week'].
#     capital-gain   has parents ['hours-per-week', 'occupation', 'income>50K'].
#     age            has parents ['race', 'relationship', 'sex'].
#     capital-loss   has parents ['hours-per-week', 'relationship', 'workclass'].
# FairPrivbayes
# Constructed Bayesian network:
#     fnlwgt         has parents ['sex'].
#     workclass      has parents ['fnlwgt', 'sex'].
#     education-num  has parents ['fnlwgt', 'workclass', 'sex'].
#     native-country has parents ['workclass', 'education-num', 'sex'].
#     capital-loss   has parents ['workclass', 'education-num', 'sex'].
#     capital-gain   has parents ['fnlwgt', 'education-num', 'sex'].
#     marital-status has parents ['native-country', 'capital-gain', 'workclass'].
#     age            has parents ['native-country', 'marital-status', 'workclass'].
#     race           has parents ['fnlwgt', 'age', 'sex'].
#     occupation     has parents ['capital-loss', 'race', 'fnlwgt'].
#     hours-per-week has parents ['capital-gain', 'age', 'sex'].
#     relationship   has parents ['occupation', 'hours-per-week', 'sex'].
#     income>50K     has parents ['education-num', 'occupation', 'workclass'].
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT relationship
# Adding attribute income>50K
# Adding attribute age
# Adding attribute education-num
# Adding attribute sex
# Adding attribute occupation
# Adding attribute race
# Adding attribute fnlwgt
# Adding attribute hours-per-week
# Adding attribute capital-loss
# Adding attribute native-country
# Adding attribute marital-status
# Adding attribute workclass
# Adding attribute capital-gain
# ========================== BN constructed ==========================
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT relationship
# Adding attribute fnlwgt
# Adding attribute age
# Adding attribute occupation
# Adding attribute marital-status
# Adding attribute education-num
# Adding attribute workclass
# Adding attribute capital-gain
# Adding attribute sex
# Adding attribute race
# Adding attribute capital-loss
# Adding attribute native-country
# Adding attribute hours-per-week
# Adding attribute income>50K
# ========================== BN constructed ==========================
# Privbayes
# Constructed Bayesian network:
#     income>50K     has parents ['relationship'].
#     age            has parents ['income>50K', 'relationship'].
#     education-num  has parents ['income>50K', 'age', 'relationship'].
#     sex            has parents ['age', 'education-num', 'income>50K'].
#     occupation     has parents ['age', 'sex', 'relationship'].
#     race           has parents ['sex', 'occupation', 'relationship'].
#     fnlwgt         has parents ['education-num', 'race', 'age'].
#     hours-per-week has parents ['race', 'fnlwgt', 'relationship'].
#     capital-loss   has parents ['education-num', 'hours-per-week', 'relationship'].
#     native-country has parents ['education-num', 'sex', 'income>50K'].
#     marital-status has parents ['education-num', 'native-country', 'age'].
#     workclass      has parents ['race', 'native-country', 'age'].
#     capital-gain   has parents ['race', 'workclass', 'occupation'].
# FairPrivbayes
# Constructed Bayesian network:
#     fnlwgt         has parents ['relationship'].
#     age            has parents ['fnlwgt', 'relationship'].
#     occupation     has parents ['fnlwgt', 'age', 'relationship'].
#     marital-status has parents ['fnlwgt', 'occupation', 'relationship'].
#     education-num  has parents ['fnlwgt', 'age', 'relationship'].
#     workclass      has parents ['age', 'marital-status', 'relationship'].
#     capital-gain   has parents ['occupation', 'workclass', 'fnlwgt'].
#     sex            has parents ['age', 'capital-gain', 'relationship'].
#     race           has parents ['education-num', 'workclass', 'marital-status'].
#     capital-loss   has parents ['occupation', 'sex', 'age'].
#     native-country has parents ['age', 'capital-gain', 'fnlwgt'].
#     hours-per-week has parents ['race', 'native-country', 'workclass'].
#     income>50K     has parents ['fnlwgt', 'occupation', 'workclass'].

# %% [markdown]
# # Compas

# %%
# input dataset
input_data = './data/cleaned_Compas.csv'
# location of two output files
mode = 'correlated_attribute_mode'
description_file = f'./out/{mode}/description.json'
description_file_fair = f'./out/{mode}/description_fair.json'
synthetic_data = f'./out/{mode}/sythetic_data.csv'
sythetic_data_fair= f'./out/{mode}/sythetic_data_fair.csv'

# %%
# An attribute is categorical if its domain size is less than this threshold.
# Here modify the threshold to adapt to the domain size of "education" (which is 14 in input dataset).
threshold_value = 30

# specify categorical attributes
categorical_attributes = {}

# specify which attributes are candidate keys of input dataset.
candidate_keys = {}

# A parameter in Differential Privacy. It roughly means that removing a row in the input dataset will not 
# change the probability of getting the same output more than a multiplicative difference of exp(epsilon).
# Increase epsilon value to reduce the injected noises. Set epsilon=0 to turn off differential privacy.

# The maximum number of parents in Bayesian network, i.e., the maximum number of incoming edges.
degree_of_bayesian_network = 0

# Number of tuples generated in synthetic dataset.
num_tuples_to_generate = 6173 # Here 32561 is the same as input dataset, but it can be set to another number.

sensitive_attributes = {"admissible": ['Misdemeanor','Number_of_Priors'], "inadmissible": ['Sex','Race'], "outcome":['Two_yr_Recidivism']}

# %%
eps = [1000,100,10 ,1 , 0.1]

for e in eps:
    for i in range(10):
        randseed = int.from_bytes(os.urandom(4), 'big')
        describer = DataDescriber(category_threshold=threshold_value)
        describer_fair = DataDescriber(category_threshold=threshold_value)

        describer.describe_dataset_in_correlated_attribute_mode(dataset_file=input_data, 
                                                                epsilon=e, 
                                                                k=degree_of_bayesian_network,
                                                                attribute_to_is_categorical=categorical_attributes,
                                                                attribute_to_is_candidate_key=candidate_keys,
                                                               seed = randseed)
        describer.save_dataset_description_to_file(description_file)

        describer_fair.describe_dataset_in_fair_correlated_attribute_mode(dataset_file=input_data, 
                                                                epsilon=e, 
                                                                k=degree_of_bayesian_network,
                                                                attribute_to_is_categorical=categorical_attributes,
                                                                attribute_to_is_candidate_key=candidate_keys,
                                                                attribute_to_sensitive = sensitive_attributes,
                                                                seed = randseed)
        describer_fair.save_dataset_description_to_file(description_file_fair)


        print("Privbayes")
        display_bayesian_network(describer.bayesian_network)
        print("FairPrivbayes")
        display_bayesian_network(describer_fair.bayesian_network)

        synthpath = f'./out/{mode}/Bayes_original/eps={e}/sythetic_data_{i}.csv'
        fairsynthpath = f'./out/{mode}/Bayes_fair/eps={e}/sythetic_data_{i}.csv'
        generator = DataGenerator()
        generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file)
        generator.save_synthetic_data(synthpath)

        generator = DataGenerator()
        generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file_fair)
        generator.save_synthetic_data(fairsynthpath)

# %% [markdown]
# ## Timing

# %%
eps = 10
privbayes_times_10 = []
for i in range(10):
    print(str(i))
    start_time = timeit.default_timer()
    randseed = int.from_bytes(os.urandom(4), 'big')
    describer = DataDescriber(category_threshold=threshold_value)

    describer.describe_dataset_in_correlated_attribute_mode(dataset_file=input_data, 
                                                            epsilon=eps, 
                                                            k=degree_of_bayesian_network,
                                                            attribute_to_is_categorical=categorical_attributes,
                                                            attribute_to_is_candidate_key=candidate_keys,
                                                           seed = randseed)
    describer.save_dataset_description_to_file(description_file)
    

    generator = DataGenerator()
    generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file)
    elapsed = timeit.default_timer() - start_time
    privbayes_times_10.append(elapsed)
print(privbayes_times_10)
# Out:
# 0
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute education-num
# Adding attribute occupation
# Adding attribute workclass
# Adding attribute income>50K
# Adding attribute native-country
# Adding attribute relationship
# Adding attribute capital-loss
# Adding attribute hours-per-week
# Adding attribute race
# Adding attribute marital-status
# Adding attribute fnlwgt
# Adding attribute capital-gain
# Adding attribute age
# ========================== BN constructed ==========================
# 1
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT capital-loss
# Adding attribute sex
# Adding attribute income>50K
# Adding attribute native-country
# Adding attribute race
# Adding attribute marital-status
# Adding attribute capital-gain
# Adding attribute hours-per-week
# Adding attribute age
# Adding attribute occupation
# Adding attribute education-num
# Adding attribute fnlwgt
# Adding attribute relationship
# Adding attribute workclass
# ========================== BN constructed ==========================
# 2
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT relationship
# Adding attribute capital-gain
# Adding attribute fnlwgt
# Adding attribute marital-status
# Adding attribute workclass
# Adding attribute sex
# Adding attribute education-num
# Adding attribute age
# Adding attribute capital-loss
# Adding attribute hours-per-week
# Adding attribute native-country
# Adding attribute race
# Adding attribute income>50K
# Adding attribute occupation
# ========================== BN constructed ==========================
# 3
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT education-num
# Adding attribute marital-status
# Adding attribute race
# Adding attribute relationship
# Adding attribute occupation
# Adding attribute workclass
# Adding attribute income>50K
# Adding attribute native-country
# Adding attribute fnlwgt
# Adding attribute age
# Adding attribute capital-loss
# Adding attribute sex
# Adding attribute capital-gain
# Adding attribute hours-per-week
# ========================== BN constructed ==========================
# 4
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT relationship
# Adding attribute occupation
# Adding attribute capital-gain
# Adding attribute marital-status
# Adding attribute hours-per-week
# Adding attribute native-country
# Adding attribute education-num
# Adding attribute income>50K
# Adding attribute capital-loss
# Adding attribute age
# Adding attribute workclass
# Adding attribute sex
# Adding attribute fnlwgt
# Adding attribute race
# ========================== BN constructed ==========================
# 5
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT hours-per-week
# Adding attribute age
# Adding attribute marital-status
# Adding attribute income>50K
# Adding attribute workclass
# Adding attribute education-num
# Adding attribute capital-gain
# Adding attribute sex
# Adding attribute occupation
# Adding attribute fnlwgt
# Adding attribute capital-loss
# Adding attribute race
# Adding attribute relationship
# Adding attribute native-country
# ========================== BN constructed ==========================
# 6
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT native-country
# Adding attribute workclass
# Adding attribute capital-gain
# Adding attribute marital-status
# Adding attribute capital-loss
# Adding attribute sex
# Adding attribute age
# Adding attribute relationship
# Adding attribute fnlwgt
# Adding attribute income>50K
# Adding attribute occupation
# Adding attribute hours-per-week
# Adding attribute race
# Adding attribute education-num
# ========================== BN constructed ==========================
# 7
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT race
# Adding attribute education-num
# Adding attribute fnlwgt
# Adding attribute marital-status
# Adding attribute occupation
# Adding attribute capital-gain
# Adding attribute capital-loss
# Adding attribute age
# Adding attribute workclass
# Adding attribute sex
# Adding attribute income>50K
# Adding attribute native-country
# Adding attribute relationship
# Adding attribute hours-per-week
# ========================== BN constructed ==========================
# 8
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT capital-loss
# Adding attribute native-country
# Adding attribute relationship
# Adding attribute marital-status
# Adding attribute workclass
# Adding attribute fnlwgt
# Adding attribute capital-gain
# Adding attribute income>50K
# Adding attribute race
# Adding attribute age
# Adding attribute education-num
# Adding attribute sex
# Adding attribute hours-per-week
# Adding attribute occupation
# ========================== BN constructed ==========================
# 9
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute workclass
# Adding attribute marital-status
# Adding attribute occupation
# Adding attribute native-country
# Adding attribute race
# Adding attribute capital-gain
# Adding attribute hours-per-week
# Adding attribute fnlwgt
# Adding attribute education-num
# Adding attribute relationship
# Adding attribute capital-loss
# Adding attribute income>50K
# Adding attribute age
# ========================== BN constructed ==========================
# [709.1196924240003, 552.8267354289997, 635.2578249819999, 487.66905089500005, 571.2252423820005, 701.8194232989999, 559.1132342890005, 650.6617965179994, 723.3966087499994, 478.0632027439997]

# %%
eps = 1
privbayes_times_1 = []
for i in range(10):
    print(str(i))
    start_time = timeit.default_timer()
    randseed = int.from_bytes(os.urandom(4), 'big')
    describer = DataDescriber(category_threshold=threshold_value)

    describer.describe_dataset_in_correlated_attribute_mode(dataset_file=input_data, 
                                                            epsilon=eps, 
                                                            k=degree_of_bayesian_network,
                                                            attribute_to_is_categorical=categorical_attributes,
                                                            attribute_to_is_candidate_key=candidate_keys,
                                                           seed = randseed)
    describer.save_dataset_description_to_file(description_file)
    

    generator = DataGenerator()
    generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file)
    elapsed = timeit.default_timer() - start_time
    privbayes_times_1.append(elapsed)
print(privbayes_times_1)
# Out:
# 0
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT occupation
# Adding attribute capital-loss
# Adding attribute income>50K
# Adding attribute marital-status
# Adding attribute relationship
# Adding attribute workclass
# Adding attribute sex
# Adding attribute age
# Adding attribute fnlwgt
# Adding attribute race
# Adding attribute native-country
# Adding attribute education-num
# Adding attribute hours-per-week
# Adding attribute capital-gain
# ========================== BN constructed ==========================
# 1
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT education-num
# Adding attribute age
# Adding attribute relationship
# Adding attribute capital-loss
# Adding attribute sex
# Adding attribute workclass
# Adding attribute race
# Adding attribute marital-status
# Adding attribute income>50K
# Adding attribute hours-per-week
# Adding attribute fnlwgt
# Adding attribute native-country
# Adding attribute occupation
# Adding attribute capital-gain
# ========================== BN constructed ==========================
# 2
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT workclass
# Adding attribute fnlwgt
# Adding attribute relationship
# Adding attribute capital-loss
# Adding attribute occupation
# Adding attribute hours-per-week
# Adding attribute sex
# Adding attribute race
# Adding attribute education-num
# Adding attribute native-country
# Adding attribute income>50K
# Adding attribute marital-status
# Adding attribute age
# Adding attribute capital-gain
# ========================== BN constructed ==========================
# 3
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT fnlwgt
# Adding attribute race
# Adding attribute workclass
# Adding attribute income>50K
# Adding attribute hours-per-week
# Adding attribute sex
# Adding attribute capital-gain
# Adding attribute capital-loss
# Adding attribute occupation
# Adding attribute relationship
# Adding attribute age
# Adding attribute native-country
# Adding attribute marital-status
# Adding attribute education-num
# ========================== BN constructed ==========================
# 4
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT native-country
# Adding attribute occupation
# Adding attribute capital-loss
# Adding attribute marital-status
# Adding attribute education-num
# Adding attribute fnlwgt
# Adding attribute age
# Adding attribute capital-gain
# Adding attribute sex
# Adding attribute race
# Adding attribute relationship
# Adding attribute income>50K
# Adding attribute hours-per-week
# Adding attribute workclass
# ========================== BN constructed ==========================
# 5
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT education-num
# Adding attribute age
# Adding attribute fnlwgt
# Adding attribute income>50K
# Adding attribute capital-gain
# Adding attribute occupation
# Adding attribute marital-status
# Adding attribute sex
# Adding attribute capital-loss
# Adding attribute relationship
# Adding attribute race
# Adding attribute hours-per-week
# Adding attribute native-country
# Adding attribute workclass
# ========================== BN constructed ==========================
# 6
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT hours-per-week
# Adding attribute education-num
# Adding attribute capital-gain
# Adding attribute income>50K
# Adding attribute race
# Adding attribute occupation
# Adding attribute native-country
# Adding attribute capital-loss
# Adding attribute relationship
# Adding attribute sex
# Adding attribute marital-status
# Adding attribute workclass
# Adding attribute fnlwgt
# Adding attribute age
# ========================== BN constructed ==========================
# 7
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT race
# Adding attribute income>50K
# Adding attribute sex
# Adding attribute age
# Adding attribute education-num
# Adding attribute capital-loss
# Adding attribute workclass
# Adding attribute hours-per-week
# Adding attribute occupation
# Adding attribute relationship
# Adding attribute marital-status
# Adding attribute native-country
# Adding attribute capital-gain
# Adding attribute fnlwgt
# ========================== BN constructed ==========================
# 8
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute race
# Adding attribute occupation
# Adding attribute capital-loss
# Adding attribute relationship
# Adding attribute capital-gain
# Adding attribute hours-per-week
# Adding attribute native-country
# Adding attribute income>50K
# Adding attribute marital-status
# Adding attribute age
# Adding attribute fnlwgt
# Adding attribute workclass
# Adding attribute education-num
# ========================== BN constructed ==========================
# 9
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT native-country
# Adding attribute capital-loss
# Adding attribute marital-status
# Adding attribute occupation
# Adding attribute fnlwgt
# Adding attribute sex
# Adding attribute workclass
# Adding attribute hours-per-week
# Adding attribute education-num
# Adding attribute age
# Adding attribute race
# Adding attribute income>50K
# Adding attribute capital-gain
# Adding attribute relationship
# ========================== BN constructed ==========================
# [403.147964023, 414.11422147199994, 475.91907266399994, 368.26080932399987, 612.595638284, 578.6659734749996, 576.2117977170001, 350.0807570840002, 351.50060758499967, 588.4299071820005]

# %%
eps = 0.1
privbayes_times_01 = []
for i in range(10):
    print(str(i))
    start_time = timeit.default_timer()
    randseed = int.from_bytes(os.urandom(4), 'big')
    describer = DataDescriber(category_threshold=threshold_value)

    describer.describe_dataset_in_correlated_attribute_mode(dataset_file=input_data, 
                                                            epsilon=eps, 
                                                            k=degree_of_bayesian_network,
                                                            attribute_to_is_categorical=categorical_attributes,
                                                            attribute_to_is_candidate_key=candidate_keys,
                                                           seed = randseed)
    describer.save_dataset_description_to_file(description_file)
    

    generator = DataGenerator()
    generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file)
    elapsed = timeit.default_timer() - start_time
    privbayes_times_01.append(elapsed)
print(privbayes_times_01)
# Out:
# 0
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute workclass
# Adding attribute capital-gain
# Adding attribute relationship
# Adding attribute marital-status
# Adding attribute income>50K
# Adding attribute age
# Adding attribute occupation
# Adding attribute education-num
# Adding attribute native-country
# Adding attribute race
# Adding attribute fnlwgt
# Adding attribute hours-per-week
# Adding attribute capital-loss
# ========================== BN constructed ==========================
# 1
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT relationship
# Adding attribute income>50K
# Adding attribute capital-gain
# Adding attribute fnlwgt
# Adding attribute native-country
# Adding attribute occupation
# Adding attribute race
# Adding attribute education-num
# Adding attribute age
# Adding attribute workclass
# Adding attribute hours-per-week
# Adding attribute sex
# Adding attribute capital-loss
# Adding attribute marital-status
# ========================== BN constructed ==========================
# 2
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT native-country
# Adding attribute age
# Adding attribute marital-status
# Adding attribute fnlwgt
# Adding attribute education-num
# Adding attribute capital-gain
# Adding attribute hours-per-week
# Adding attribute occupation
# Adding attribute capital-loss
# Adding attribute race
# Adding attribute relationship
# Adding attribute sex
# Adding attribute income>50K
# Adding attribute workclass
# ========================== BN constructed ==========================
# 3
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT capital-gain
# Adding attribute income>50K
# Adding attribute age
# Adding attribute hours-per-week
# Adding attribute marital-status
# Adding attribute sex
# Adding attribute occupation
# Adding attribute capital-loss
# Adding attribute fnlwgt
# Adding attribute education-num
# Adding attribute relationship
# Adding attribute workclass
# Adding attribute native-country
# Adding attribute race
# ========================== BN constructed ==========================
# 4
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute age
# Adding attribute fnlwgt
# Adding attribute workclass
# Adding attribute marital-status
# Adding attribute education-num
# Adding attribute occupation
# Adding attribute relationship
# Adding attribute income>50K
# Adding attribute capital-gain
# Adding attribute capital-loss
# Adding attribute race
# Adding attribute hours-per-week
# Adding attribute native-country
# ========================== BN constructed ==========================
# 5
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT occupation
# Adding attribute hours-per-week
# Adding attribute capital-loss
# Adding attribute native-country
# Adding attribute capital-gain
# Adding attribute workclass
# Adding attribute race
# Adding attribute education-num
# Adding attribute fnlwgt
# Adding attribute age
# Adding attribute income>50K
# Adding attribute relationship
# Adding attribute sex
# Adding attribute marital-status
# ========================== BN constructed ==========================
# 6
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT race
# Adding attribute native-country
# Adding attribute fnlwgt
# Adding attribute workclass
# Adding attribute occupation
# Adding attribute capital-loss
# Adding attribute sex
# Adding attribute education-num
# Adding attribute capital-gain
# Adding attribute income>50K
# Adding attribute hours-per-week
# Adding attribute age
# Adding attribute relationship
# Adding attribute marital-status
# ========================== BN constructed ==========================
# 7
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute fnlwgt
# Adding attribute income>50K
# Adding attribute occupation
# Adding attribute capital-gain
# Adding attribute race
# Adding attribute marital-status
# Adding attribute capital-loss
# Adding attribute age
# Adding attribute hours-per-week
# Adding attribute workclass
# Adding attribute native-country
# Adding attribute education-num
# Adding attribute relationship
# ========================== BN constructed ==========================
# 8
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute occupation
# Adding attribute race
# Adding attribute income>50K
# Adding attribute education-num
# Adding attribute workclass
# Adding attribute age
# Adding attribute marital-status
# Adding attribute capital-gain
# Adding attribute hours-per-week
# Adding attribute capital-loss
# Adding attribute fnlwgt
# Adding attribute native-country
# Adding attribute relationship
# ========================== BN constructed ==========================
# 9
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT hours-per-week
# Adding attribute fnlwgt
# Adding attribute capital-gain
# Adding attribute occupation
# Adding attribute capital-loss
# Adding attribute marital-status
# Adding attribute sex
# Adding attribute income>50K
# Adding attribute age
# Adding attribute native-country
# Adding attribute education-num
# Adding attribute race
# Adding attribute workclass
# Adding attribute relationship
# ========================== BN constructed ==========================
# [434.9047455179998, 402.2502632779997, 745.6433521700001, 376.6989747300004, 461.21784439600015, 651.7838081740001, 468.3222405410006, 446.15995398700034, 428.8393825229996, 672.666025647999]

# %%
eps = 100
privbayes_times_100 = []
for i in range(10):
    print(str(i))
    start_time = timeit.default_timer()
    randseed = int.from_bytes(os.urandom(4), 'big')
    describer = DataDescriber(category_threshold=threshold_value)

    describer.describe_dataset_in_correlated_attribute_mode(dataset_file=input_data, 
                                                            epsilon=eps, 
                                                            k=degree_of_bayesian_network,
                                                            attribute_to_is_categorical=categorical_attributes,
                                                            attribute_to_is_candidate_key=candidate_keys,
                                                           seed = randseed)
    describer.save_dataset_description_to_file(description_file)
    

    generator = DataGenerator()
    generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file)
    elapsed = timeit.default_timer() - start_time
    privbayes_times_100.append(elapsed)
print(privbayes_times_100)
# Out:
# 0
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT marital-status
# Adding attribute education-num
# Adding attribute capital-gain
# Adding attribute sex
# Adding attribute workclass
# Adding attribute occupation
# Adding attribute race
# Adding attribute fnlwgt
# Adding attribute capital-loss
# Adding attribute native-country
# Adding attribute age
# Adding attribute relationship
# Adding attribute income>50K
# Adding attribute hours-per-week
# ========================== BN constructed ==========================
# 1
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT marital-status
# Adding attribute income>50K
# Adding attribute sex
# Adding attribute occupation
# Adding attribute race
# Adding attribute hours-per-week
# Adding attribute capital-gain
# Adding attribute native-country
# Adding attribute capital-loss
# Adding attribute fnlwgt
# Adding attribute relationship
# Adding attribute education-num
# Adding attribute age
# Adding attribute workclass
# ========================== BN constructed ==========================
# 2
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT capital-loss
# Adding attribute income>50K
# Adding attribute education-num
# Adding attribute native-country
# Adding attribute workclass
# Adding attribute relationship
# Adding attribute capital-gain
# Adding attribute race
# Adding attribute occupation
# Adding attribute age
# Adding attribute hours-per-week
# Adding attribute marital-status
# Adding attribute fnlwgt
# Adding attribute sex
# ========================== BN constructed ==========================
# 3
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT capital-loss
# Adding attribute age
# Adding attribute capital-gain
# Adding attribute sex
# Adding attribute workclass
# Adding attribute fnlwgt
# Adding attribute relationship
# Adding attribute income>50K
# Adding attribute education-num
# Adding attribute native-country
# Adding attribute marital-status
# Adding attribute occupation
# Adding attribute hours-per-week
# Adding attribute race
# ========================== BN constructed ==========================
# 4
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT capital-gain
# Adding attribute native-country
# Adding attribute relationship
# Adding attribute race
# Adding attribute capital-loss
# Adding attribute age
# Adding attribute occupation
# Adding attribute education-num
# Adding attribute fnlwgt
# Adding attribute hours-per-week
# Adding attribute workclass
# Adding attribute income>50K
# Adding attribute marital-status
# Adding attribute sex
# ========================== BN constructed ==========================
# 5
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute marital-status
# Adding attribute hours-per-week
# Adding attribute workclass
# Adding attribute fnlwgt
# Adding attribute age
# Adding attribute education-num
# Adding attribute capital-loss
# Adding attribute race
# Adding attribute income>50K
# Adding attribute native-country
# Adding attribute occupation
# Adding attribute relationship
# Adding attribute capital-gain
# ========================== BN constructed ==========================
# 6
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT marital-status
# Adding attribute fnlwgt
# Adding attribute sex
# Adding attribute income>50K
# Adding attribute capital-loss
# Adding attribute capital-gain
# Adding attribute education-num
# Adding attribute workclass
# Adding attribute age
# Adding attribute occupation
# Adding attribute race
# Adding attribute hours-per-week
# Adding attribute relationship
# Adding attribute native-country
# ========================== BN constructed ==========================
# 7
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT race
# Adding attribute marital-status
# Adding attribute hours-per-week
# Adding attribute education-num
# Adding attribute relationship
# Adding attribute age
# Adding attribute occupation
# Adding attribute native-country
# Adding attribute sex
# Adding attribute capital-loss
# Adding attribute income>50K
# Adding attribute capital-gain
# Adding attribute workclass
# Adding attribute fnlwgt
# ========================== BN constructed ==========================
# 8
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT age
# Adding attribute native-country
# Adding attribute race
# Adding attribute workclass
# Adding attribute fnlwgt
# Adding attribute occupation
# Adding attribute relationship
# Adding attribute sex
# Adding attribute capital-loss
# Adding attribute education-num
# Adding attribute income>50K
# Adding attribute marital-status
# Adding attribute hours-per-week
# Adding attribute capital-gain
# ========================== BN constructed ==========================
# 9
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT occupation
# Adding attribute age
# Adding attribute marital-status
# Adding attribute sex
# Adding attribute workclass
# Adding attribute fnlwgt
# Adding attribute relationship
# Adding attribute hours-per-week
# Adding attribute native-country
# Adding attribute race
# Adding attribute capital-gain
# Adding attribute capital-loss
# Adding attribute income>50K
# Adding attribute education-num
# ========================== BN constructed ==========================
# [552.4277643709993, 351.71780579500046, 396.8121602050014, 464.02826633899895, 552.5335560849999, 377.3097430430007, 468.7433697029992, 416.37947899199935, 477.33529816699956, 444.03767413400055]

# %%
eps = 1000
privbayes_times_1000 = []
for i in range(10):
    print(str(i))
    start_time = timeit.default_timer()
    randseed = int.from_bytes(os.urandom(4), 'big')
    describer = DataDescriber(category_threshold=threshold_value)

    describer.describe_dataset_in_correlated_attribute_mode(dataset_file=input_data, 
                                                            epsilon=eps, 
                                                            k=degree_of_bayesian_network,
                                                            attribute_to_is_categorical=categorical_attributes,
                                                            attribute_to_is_candidate_key=candidate_keys,
                                                           seed = randseed)
    describer.save_dataset_description_to_file(description_file)
    

    generator = DataGenerator()
    generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file)
    elapsed = timeit.default_timer() - start_time
    privbayes_times_1000.append(elapsed)
print(privbayes_times_1000)
# Out:
# 0
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT education-num
# Adding attribute race
# Adding attribute age
# Adding attribute native-country
# Adding attribute income>50K
# Adding attribute relationship
# Adding attribute marital-status
# Adding attribute sex
# Adding attribute hours-per-week
# Adding attribute fnlwgt
# Adding attribute workclass
# Adding attribute capital-gain
# Adding attribute capital-loss
# Adding attribute occupation
# ========================== BN constructed ==========================
# 1
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT occupation
# Adding attribute capital-loss
# Adding attribute fnlwgt
# Adding attribute native-country
# Adding attribute hours-per-week
# Adding attribute workclass
# Adding attribute income>50K
# Adding attribute age
# Adding attribute sex
# Adding attribute capital-gain
# Adding attribute race
# Adding attribute relationship
# Adding attribute education-num
# Adding attribute marital-status
# ========================== BN constructed ==========================
# 2
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT education-num
# Adding attribute hours-per-week
# Adding attribute fnlwgt
# Adding attribute marital-status
# Adding attribute native-country
# Adding attribute relationship
# Adding attribute income>50K
# Adding attribute workclass
# Adding attribute race
# Adding attribute age
# Adding attribute capital-loss
# Adding attribute capital-gain
# Adding attribute occupation
# Adding attribute sex
# ========================== BN constructed ==========================
# 3
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT education-num
# Adding attribute income>50K
# Adding attribute hours-per-week
# Adding attribute occupation
# Adding attribute native-country
# Adding attribute age
# Adding attribute race
# Adding attribute fnlwgt
# Adding attribute relationship
# Adding attribute capital-gain
# Adding attribute workclass
# Adding attribute capital-loss
# Adding attribute marital-status
# Adding attribute sex
# ========================== BN constructed ==========================
# 4
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT relationship
# Adding attribute fnlwgt
# Adding attribute marital-status
# Adding attribute capital-gain
# Adding attribute occupation
# Adding attribute capital-loss
# Adding attribute age
# Adding attribute native-country
# Adding attribute race
# Adding attribute hours-per-week
# Adding attribute education-num
# Adding attribute income>50K
# Adding attribute sex
# Adding attribute workclass
# ========================== BN constructed ==========================
# 5
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute native-country
# Adding attribute capital-loss
# Adding attribute race
# Adding attribute occupation
# Adding attribute education-num
# Adding attribute capital-gain
# Adding attribute income>50K
# Adding attribute age
# Adding attribute marital-status
# Adding attribute fnlwgt
# Adding attribute hours-per-week
# Adding attribute workclass
# Adding attribute relationship
# ========================== BN constructed ==========================
# 6
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT relationship
# Adding attribute education-num
# Adding attribute hours-per-week
# Adding attribute income>50K
# Adding attribute marital-status
# Adding attribute native-country
# Adding attribute fnlwgt
# Adding attribute workclass
# Adding attribute capital-loss
# Adding attribute occupation
# Adding attribute capital-gain
# Adding attribute race
# Adding attribute sex
# Adding attribute age
# ========================== BN constructed ==========================
# 7
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT income>50K
# Adding attribute age
# Adding attribute education-num
# Adding attribute fnlwgt
# Adding attribute sex
# Adding attribute native-country
# Adding attribute race
# Adding attribute marital-status
# Adding attribute workclass
# Adding attribute capital-loss
# Adding attribute hours-per-week
# Adding attribute capital-gain
# Adding attribute occupation
# Adding attribute relationship
# ========================== BN constructed ==========================
# 8
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT marital-status
# Adding attribute education-num
# Adding attribute occupation
# Adding attribute capital-gain
# Adding attribute fnlwgt
# Adding attribute capital-loss
# Adding attribute hours-per-week
# Adding attribute relationship
# Adding attribute workclass
# Adding attribute sex
# Adding attribute age
# Adding attribute native-country
# Adding attribute income>50K
# Adding attribute race
# ========================== BN constructed ==========================
# 9
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT race
# Adding attribute capital-gain
# Adding attribute capital-loss
# Adding attribute workclass
# Adding attribute age
# Adding attribute income>50K
# Adding attribute education-num
# Adding attribute hours-per-week
# Adding attribute native-country
# Adding attribute occupation
# Adding attribute fnlwgt
# Adding attribute relationship
# Adding attribute marital-status
# Adding attribute sex
# ========================== BN constructed ==========================
# [401.0636971189997, 523.9745349959994, 614.3947924630011, 558.0282866090001, 542.3041621699995, 492.80772217900085, 575.026929366999, 370.7590321150019, 553.141534937, 514.9456108230006]

# %%
eps = 10
fair_privbayes_times_10 = []
for i in range(10):
    print(str(i))
    start_time = timeit.default_timer()
    randseed = int.from_bytes(os.urandom(4), 'big')
    describer_fair = DataDescriber(category_threshold=threshold_value)

    describer_fair.describe_dataset_in_fair_correlated_attribute_mode(dataset_file=input_data, 
                                                                epsilon=eps, 
                                                                k=degree_of_bayesian_network,
                                                                attribute_to_is_categorical=categorical_attributes,
                                                                attribute_to_is_candidate_key=candidate_keys,
                                                                attribute_to_sensitive = sensitive_attributes,
                                                                seed = randseed)
    describer_fair.save_dataset_description_to_file(description_file_fair)
    

    generator = DataGenerator()
    generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file)
    elapsed = timeit.default_timer() - start_time
    fair_privbayes_times_10.append(elapsed)
print(fair_privbayes_times_10)
# Out:
# 0
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT age
# Adding attribute hours-per-week
# Adding attribute capital-gain
# Adding attribute sex
# Adding attribute relationship
# Adding attribute education-num
# Adding attribute race
# Adding attribute marital-status
# Adding attribute fnlwgt
# Adding attribute native-country
# Adding attribute capital-loss
# Adding attribute occupation
# Adding attribute workclass
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 1
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT race
# Adding attribute age
# Adding attribute capital-gain
# Adding attribute capital-loss
# Adding attribute relationship
# Adding attribute workclass
# Adding attribute hours-per-week
# Adding attribute marital-status
# Adding attribute occupation
# Adding attribute native-country
# Adding attribute sex
# Adding attribute fnlwgt
# Adding attribute education-num
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 2
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT marital-status
# Adding attribute capital-loss
# Adding attribute hours-per-week
# Adding attribute race
# Adding attribute relationship
# Adding attribute education-num
# Adding attribute sex
# Adding attribute fnlwgt
# Adding attribute capital-gain
# Adding attribute native-country
# Adding attribute age
# Adding attribute occupation
# Adding attribute workclass
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 3
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT relationship
# Adding attribute fnlwgt
# Adding attribute capital-loss
# Adding attribute sex
# Adding attribute marital-status
# Adding attribute native-country
# Adding attribute race
# Adding attribute education-num
# Adding attribute workclass
# Adding attribute capital-gain
# Adding attribute occupation
# Adding attribute age
# Adding attribute hours-per-week
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 4
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT age
# Adding attribute capital-gain
# Adding attribute race
# Adding attribute education-num
# Adding attribute relationship
# Adding attribute fnlwgt
# Adding attribute marital-status
# Adding attribute occupation
# Adding attribute capital-loss
# Adding attribute hours-per-week
# Adding attribute sex
# Adding attribute native-country
# Adding attribute workclass
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 5
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT marital-status
# Adding attribute native-country
# Adding attribute race
# Adding attribute age
# Adding attribute capital-loss
# Adding attribute capital-gain
# Adding attribute fnlwgt
# Adding attribute occupation
# Adding attribute workclass
# Adding attribute sex
# Adding attribute education-num
# Adding attribute relationship
# Adding attribute hours-per-week
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 6
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT fnlwgt
# Adding attribute relationship
# Adding attribute education-num
# Adding attribute capital-gain
# Adding attribute marital-status
# Adding attribute occupation
# Adding attribute age
# Adding attribute hours-per-week
# Adding attribute workclass
# Adding attribute race
# Adding attribute sex
# Adding attribute capital-loss
# Adding attribute native-country
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 7
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT race
# Adding attribute marital-status
# Adding attribute education-num
# Adding attribute workclass
# Adding attribute fnlwgt
# Adding attribute capital-loss
# Adding attribute hours-per-week
# Adding attribute native-country
# Adding attribute capital-gain
# Adding attribute age
# Adding attribute relationship
# Adding attribute occupation
# Adding attribute sex
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 8
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT capital-loss
# Adding attribute relationship
# Adding attribute workclass
# Adding attribute fnlwgt
# Adding attribute sex
# Adding attribute capital-gain
# Adding attribute native-country
# Adding attribute education-num
# Adding attribute marital-status
# Adding attribute occupation
# Adding attribute hours-per-week
# Adding attribute age
# Adding attribute race
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 9
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT fnlwgt
# Adding attribute capital-gain
# Adding attribute relationship
# Adding attribute hours-per-week
# Adding attribute capital-loss
# Adding attribute occupation
# Adding attribute race
# Adding attribute workclass
# Adding attribute native-country
# Adding attribute sex
# Adding attribute education-num
# Adding attribute marital-status
# Adding attribute age
# Adding attribute income>50K
# ========================== BN constructed ==========================
# [417.719469507, 439.99911159500004, 408.8552680769999, 410.441795187, 445.284023701, 442.7256289789998, 441.88617572600015, 395.01128898800016, 417.68447277199994, 442.96631570499994]

# %%
eps = 1
fair_privbayes_times_1 = []
for i in range(10):
    print(str(i))
    start_time = timeit.default_timer()
    randseed = int.from_bytes(os.urandom(4), 'big')
    describer_fair = DataDescriber(category_threshold=threshold_value)

    describer_fair.describe_dataset_in_fair_correlated_attribute_mode(dataset_file=input_data, 
                                                                epsilon=eps, 
                                                                k=degree_of_bayesian_network,
                                                                attribute_to_is_categorical=categorical_attributes,
                                                                attribute_to_is_candidate_key=candidate_keys,
                                                                attribute_to_sensitive = sensitive_attributes,
                                                                seed = randseed)
    describer_fair.save_dataset_description_to_file(description_file_fair)
    

    generator = DataGenerator()
    generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file)
    elapsed = timeit.default_timer() - start_time
    fair_privbayes_times_1.append(elapsed)
print(fair_privbayes_times_1)
# Out:
# 0
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT relationship
# Adding attribute marital-status
# Adding attribute capital-loss
# Adding attribute workclass
# Adding attribute age
# Adding attribute race
# Adding attribute education-num
# Adding attribute capital-gain
# Adding attribute native-country
# Adding attribute hours-per-week
# Adding attribute sex
# Adding attribute occupation
# Adding attribute fnlwgt
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 1
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute race
# Adding attribute fnlwgt
# Adding attribute capital-gain
# Adding attribute capital-loss
# Adding attribute hours-per-week
# Adding attribute relationship
# Adding attribute workclass
# Adding attribute occupation
# Adding attribute age
# Adding attribute marital-status
# Adding attribute education-num
# Adding attribute native-country
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 2
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT workclass
# Adding attribute relationship
# Adding attribute education-num
# Adding attribute occupation
# Adding attribute capital-loss
# Adding attribute fnlwgt
# Adding attribute native-country
# Adding attribute sex
# Adding attribute capital-gain
# Adding attribute race
# Adding attribute marital-status
# Adding attribute age
# Adding attribute hours-per-week
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 3
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT age
# Adding attribute native-country
# Adding attribute workclass
# Adding attribute fnlwgt
# Adding attribute hours-per-week
# Adding attribute race
# Adding attribute sex
# Adding attribute relationship
# Adding attribute capital-loss
# Adding attribute capital-gain
# Adding attribute marital-status
# Adding attribute education-num
# Adding attribute occupation
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 4
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT occupation
# Adding attribute education-num
# Adding attribute fnlwgt
# Adding attribute native-country
# Adding attribute marital-status
# Adding attribute relationship
# Adding attribute age
# Adding attribute capital-loss
# Adding attribute capital-gain
# Adding attribute workclass
# Adding attribute sex
# Adding attribute race
# Adding attribute hours-per-week
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 5
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT age
# Adding attribute capital-gain
# Adding attribute marital-status
# Adding attribute relationship
# Adding attribute capital-loss
# Adding attribute workclass
# Adding attribute hours-per-week
# Adding attribute native-country
# Adding attribute race
# Adding attribute occupation
# Adding attribute fnlwgt
# Adding attribute sex
# Adding attribute education-num
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 6
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT age
# Adding attribute sex
# Adding attribute race
# Adding attribute capital-loss
# Adding attribute capital-gain
# Adding attribute fnlwgt
# Adding attribute relationship
# Adding attribute education-num
# Adding attribute native-country
# Adding attribute marital-status
# Adding attribute hours-per-week
# Adding attribute workclass
# Adding attribute occupation
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 7
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute hours-per-week
# Adding attribute native-country
# Adding attribute marital-status
# Adding attribute occupation
# Adding attribute fnlwgt
# Adding attribute age
# Adding attribute education-num
# Adding attribute workclass
# Adding attribute capital-gain
# Adding attribute race
# Adding attribute capital-loss
# Adding attribute relationship
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 8
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT capital-loss
# Adding attribute relationship
# Adding attribute hours-per-week
# Adding attribute occupation
# Adding attribute race
# Adding attribute age
# Adding attribute native-country
# Adding attribute workclass
# Adding attribute education-num
# Adding attribute sex
# Adding attribute fnlwgt
# Adding attribute marital-status
# Adding attribute capital-gain
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 9
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT race
# Adding attribute age
# Adding attribute relationship
# Adding attribute capital-gain
# Adding attribute marital-status
# Adding attribute fnlwgt
# Adding attribute occupation
# Adding attribute education-num
# Adding attribute capital-loss
# Adding attribute workclass
# Adding attribute sex
# Adding attribute hours-per-week
# Adding attribute native-country
# Adding attribute income>50K
# ========================== BN constructed ==========================
# [425.285221053, 409.900992676, 437.51089728399984, 423.9541476919994, 421.4323956010003, 449.6144135200002, 419.99688412399973, 429.90856550599983, 434.94164325600104, 407.5774210180007]

# %%
eps = 0.1
fair_privbayes_times_01 = []
for i in range(10):
    print(str(i))
    start_time = timeit.default_timer()
    randseed = int.from_bytes(os.urandom(4), 'big')
    describer_fair = DataDescriber(category_threshold=threshold_value)

    describer_fair.describe_dataset_in_fair_correlated_attribute_mode(dataset_file=input_data, 
                                                                epsilon=eps, 
                                                                k=degree_of_bayesian_network,
                                                                attribute_to_is_categorical=categorical_attributes,
                                                                attribute_to_is_candidate_key=candidate_keys,
                                                                attribute_to_sensitive = sensitive_attributes,
                                                                seed = randseed)
    describer_fair.save_dataset_description_to_file(description_file_fair)
    

    generator = DataGenerator()
    generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file)
    elapsed = timeit.default_timer() - start_time
    fair_privbayes_times_01.append(elapsed)
print(fair_privbayes_times_01)
# Out:
# 0
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute relationship
# Adding attribute workclass
# Adding attribute capital-gain
# Adding attribute capital-loss
# Adding attribute hours-per-week
# Adding attribute education-num
# Adding attribute age
# Adding attribute marital-status
# Adding attribute fnlwgt
# Adding attribute native-country
# Adding attribute race
# Adding attribute occupation
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 1
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT occupation
# Adding attribute hours-per-week
# Adding attribute fnlwgt
# Adding attribute native-country
# Adding attribute education-num
# Adding attribute relationship
# Adding attribute capital-gain
# Adding attribute workclass
# Adding attribute marital-status
# Adding attribute race
# Adding attribute sex
# Adding attribute age
# Adding attribute capital-loss
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 2
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT sex
# Adding attribute education-num
# Adding attribute fnlwgt
# Adding attribute occupation
# Adding attribute capital-gain
# Adding attribute hours-per-week
# Adding attribute relationship
# Adding attribute marital-status
# Adding attribute age
# Adding attribute race
# Adding attribute capital-loss
# Adding attribute native-country
# Adding attribute workclass
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 3
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT race
# Adding attribute workclass
# Adding attribute hours-per-week
# Adding attribute capital-gain
# Adding attribute fnlwgt
# Adding attribute occupation
# Adding attribute capital-loss
# Adding attribute marital-status
# Adding attribute education-num
# Adding attribute sex
# Adding attribute relationship
# Adding attribute native-country
# Adding attribute age
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 4
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT native-country
# Adding attribute age
# Adding attribute race
# Adding attribute capital-gain
# Adding attribute hours-per-week
# Adding attribute occupation
# Adding attribute capital-loss
# Adding attribute relationship
# Adding attribute workclass
# Adding attribute education-num
# Adding attribute marital-status
# Adding attribute sex
# Adding attribute fnlwgt
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 5
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT relationship
# Adding attribute marital-status
# Adding attribute fnlwgt
# Adding attribute sex
# Adding attribute workclass
# Adding attribute race
# Adding attribute occupation
# Adding attribute age
# Adding attribute capital-loss
# Adding attribute education-num
# Adding attribute capital-gain
# Adding attribute hours-per-week
# Adding attribute native-country
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 6
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT native-country
# Adding attribute race
# Adding attribute fnlwgt
# Adding attribute workclass
# Adding attribute marital-status
# Adding attribute occupation
# Adding attribute capital-loss
# Adding attribute sex
# Adding attribute capital-gain
# Adding attribute education-num
# Adding attribute hours-per-week
# Adding attribute relationship
# Adding attribute age
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 7
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT education-num
# Adding attribute capital-gain
# Adding attribute occupation
# Adding attribute race
# Adding attribute capital-loss
# Adding attribute sex
# Adding attribute marital-status
# Adding attribute relationship
# Adding attribute hours-per-week
# Adding attribute native-country
# Adding attribute workclass
# Adding attribute fnlwgt
# Adding attribute age
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 8
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT race
# Adding attribute hours-per-week
# Adding attribute capital-gain
# Adding attribute fnlwgt
# Adding attribute marital-status
# Adding attribute native-country
# Adding attribute occupation
# Adding attribute age
# Adding attribute relationship
# Adding attribute workclass
# Adding attribute education-num
# Adding attribute capital-loss
# Adding attribute sex
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 9
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT hours-per-week
# Adding attribute native-country
# Adding attribute marital-status
# Adding attribute age
# Adding attribute race
# Adding attribute capital-loss
# Adding attribute fnlwgt
# Adding attribute relationship
# Adding attribute capital-gain
# Adding attribute sex
# Adding attribute education-num
# Adding attribute workclass
# Adding attribute occupation
# Adding attribute income>50K
# ========================== BN constructed ==========================
# [444.5952425230007, 409.52220910899996, 448.5093627789993, 442.3900634719994, 445.06131299900153, 418.35789415100044, 438.9764095900009, 406.09443238699896, 435.6718823560004, 417.799232768999]

# %%
eps = 100
fair_privbayes_times_100 = []
for i in range(10):
    print(str(i))
    start_time = timeit.default_timer()
    randseed = int.from_bytes(os.urandom(4), 'big')
    describer_fair = DataDescriber(category_threshold=threshold_value)

    describer_fair.describe_dataset_in_fair_correlated_attribute_mode(dataset_file=input_data, 
                                                                epsilon=eps, 
                                                                k=degree_of_bayesian_network,
                                                                attribute_to_is_categorical=categorical_attributes,
                                                                attribute_to_is_candidate_key=candidate_keys,
                                                                attribute_to_sensitive = sensitive_attributes,
                                                                seed = randseed)
    describer_fair.save_dataset_description_to_file(description_file_fair)
    

    generator = DataGenerator()
    generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file)
    elapsed = timeit.default_timer() - start_time
    fair_privbayes_times_100.append(elapsed)
print(fair_privbayes_times_100)
# Out:
# 0
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT native-country
# Adding attribute capital-gain
# Adding attribute relationship
# Adding attribute marital-status
# Adding attribute race
# Adding attribute occupation
# Adding attribute hours-per-week
# Adding attribute sex
# Adding attribute fnlwgt
# Adding attribute education-num
# Adding attribute age
# Adding attribute workclass
# Adding attribute capital-loss
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 1
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT fnlwgt
# Adding attribute sex
# Adding attribute education-num
# Adding attribute occupation
# Adding attribute age
# Adding attribute relationship
# Adding attribute capital-gain
# Adding attribute marital-status
# Adding attribute hours-per-week
# Adding attribute capital-loss
# Adding attribute race
# Adding attribute workclass
# Adding attribute native-country
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 2
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT hours-per-week
# Adding attribute workclass
# Adding attribute age
# Adding attribute marital-status
# Adding attribute race
# Adding attribute capital-gain
# Adding attribute native-country
# Adding attribute education-num
# Adding attribute fnlwgt
# Adding attribute sex
# Adding attribute relationship
# Adding attribute capital-loss
# Adding attribute occupation
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 3
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT fnlwgt
# Adding attribute relationship
# Adding attribute age
# Adding attribute race
# Adding attribute sex
# Adding attribute marital-status
# Adding attribute occupation
# Adding attribute education-num
# Adding attribute capital-gain
# Adding attribute workclass
# Adding attribute capital-loss
# Adding attribute native-country
# Adding attribute hours-per-week
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 4
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT fnlwgt
# Adding attribute sex
# Adding attribute workclass
# Adding attribute occupation
# Adding attribute hours-per-week
# Adding attribute native-country
# Adding attribute marital-status
# Adding attribute age
# Adding attribute relationship
# Adding attribute capital-loss
# Adding attribute education-num
# Adding attribute race
# Adding attribute capital-gain
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 5
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT marital-status
# Adding attribute sex
# Adding attribute occupation
# Adding attribute education-num
# Adding attribute capital-gain
# Adding attribute hours-per-week
# Adding attribute workclass
# Adding attribute capital-loss
# Adding attribute relationship
# Adding attribute age
# Adding attribute native-country
# Adding attribute fnlwgt
# Adding attribute race
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 6
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT race
# Adding attribute sex
# Adding attribute education-num
# Adding attribute native-country
# Adding attribute marital-status
# Adding attribute capital-gain
# Adding attribute occupation
# Adding attribute fnlwgt
# Adding attribute age
# Adding attribute relationship
# Adding attribute workclass
# Adding attribute hours-per-week
# Adding attribute capital-loss
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 7
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT race
# Adding attribute native-country
# Adding attribute hours-per-week
# Adding attribute sex
# Adding attribute marital-status
# Adding attribute capital-loss
# Adding attribute fnlwgt
# Adding attribute relationship
# Adding attribute workclass
# Adding attribute occupation
# Adding attribute age
# Adding attribute capital-gain
# Adding attribute education-num
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 8
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT hours-per-week
# Adding attribute capital-gain
# Adding attribute race
# Adding attribute capital-loss
# Adding attribute age
# Adding attribute education-num
# Adding attribute marital-status
# Adding attribute native-country
# Adding attribute fnlwgt
# Adding attribute sex
# Adding attribute relationship
# Adding attribute workclass
# Adding attribute occupation
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 9
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT relationship
# Adding attribute hours-per-week
# Adding attribute occupation
# Adding attribute race
# Adding attribute marital-status
# Adding attribute capital-gain
# Adding attribute workclass
# Adding attribute sex
# Adding attribute capital-loss
# Adding attribute fnlwgt
# Adding attribute age
# Adding attribute education-num
# Adding attribute native-country
# Adding attribute income>50K
# ========================== BN constructed ==========================
# [415.3176372559992, 417.28925964299924, 414.8009967449998, 411.70426654400035, 409.92194801000005, 442.5028995199991, 433.5300038330006, 398.2480016259997, 423.21367890500005, 407.65605854800015]

# %%
eps = 1000
fair_privbayes_times_1000 = []
for i in range(10):
    print(str(i))
    start_time = timeit.default_timer()
    randseed = int.from_bytes(os.urandom(4), 'big')
    describer_fair = DataDescriber(category_threshold=threshold_value)

    describer_fair.describe_dataset_in_fair_correlated_attribute_mode(dataset_file=input_data, 
                                                                epsilon=eps, 
                                                                k=degree_of_bayesian_network,
                                                                attribute_to_is_categorical=categorical_attributes,
                                                                attribute_to_is_candidate_key=candidate_keys,
                                                                attribute_to_sensitive = sensitive_attributes,
                                                                seed = randseed)
    describer_fair.save_dataset_description_to_file(description_file_fair)
    

    generator = DataGenerator()
    generator.generate_dataset_in_correlated_attribute_mode(num_tuples_to_generate, description_file)
    elapsed = timeit.default_timer() - start_time
    fair_privbayes_times_1000.append(elapsed)
print(fair_privbayes_times_1000)
# Out:
# 0
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT capital-gain
# Adding attribute marital-status
# Adding attribute native-country
# Adding attribute age
# Adding attribute occupation
# Adding attribute relationship
# Adding attribute hours-per-week
# Adding attribute fnlwgt
# Adding attribute race
# Adding attribute education-num
# Adding attribute capital-loss
# Adding attribute workclass
# Adding attribute sex
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 1
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT marital-status
# Adding attribute native-country
# Adding attribute race
# Adding attribute occupation
# Adding attribute fnlwgt
# Adding attribute education-num
# Adding attribute age
# Adding attribute relationship
# Adding attribute sex
# Adding attribute capital-gain
# Adding attribute capital-loss
# Adding attribute hours-per-week
# Adding attribute workclass
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 2
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT age
# Adding attribute sex
# Adding attribute occupation
# Adding attribute capital-loss
# Adding attribute marital-status
# Adding attribute race
# Adding attribute fnlwgt
# Adding attribute hours-per-week
# Adding attribute education-num
# Adding attribute relationship
# Adding attribute capital-gain
# Adding attribute native-country
# Adding attribute workclass
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 3
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT hours-per-week
# Adding attribute capital-gain
# Adding attribute native-country
# Adding attribute age
# Adding attribute workclass
# Adding attribute sex
# Adding attribute relationship
# Adding attribute capital-loss
# Adding attribute race
# Adding attribute marital-status
# Adding attribute education-num
# Adding attribute occupation
# Adding attribute fnlwgt
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 4
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT occupation
# Adding attribute workclass
# Adding attribute race
# Adding attribute capital-gain
# Adding attribute relationship
# Adding attribute sex
# Adding attribute capital-loss
# Adding attribute hours-per-week
# Adding attribute fnlwgt
# Adding attribute education-num
# Adding attribute age
# Adding attribute marital-status
# Adding attribute native-country
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 5
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT capital-gain
# Adding attribute race
# Adding attribute hours-per-week
# Adding attribute age
# Adding attribute workclass
# Adding attribute capital-loss
# Adding attribute sex
# Adding attribute education-num
# Adding attribute native-country
# Adding attribute marital-status
# Adding attribute fnlwgt
# Adding attribute relationship
# Adding attribute occupation
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 6
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT capital-loss
# Adding attribute occupation
# Adding attribute workclass
# Adding attribute race
# Adding attribute sex
# Adding attribute capital-gain
# Adding attribute education-num
# Adding attribute fnlwgt
# Adding attribute age
# Adding attribute marital-status
# Adding attribute relationship
# Adding attribute hours-per-week
# Adding attribute native-country
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 7
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT marital-status
# Adding attribute relationship
# Adding attribute race
# Adding attribute fnlwgt
# Adding attribute occupation
# Adding attribute capital-loss
# Adding attribute education-num
# Adding attribute native-country
# Adding attribute hours-per-week
# Adding attribute workclass
# Adding attribute capital-gain
# Adding attribute sex
# Adding attribute age
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 8
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT workclass
# Adding attribute sex
# Adding attribute hours-per-week
# Adding attribute marital-status
# Adding attribute capital-loss
# Adding attribute capital-gain
# Adding attribute relationship
# Adding attribute race
# Adding attribute fnlwgt
# Adding attribute age
# Adding attribute native-country
# Adding attribute occupation
# Adding attribute education-num
# Adding attribute income>50K
# ========================== BN constructed ==========================
# 9
# ================ Constructing Bayesian Network (BN) ================
# Adding ROOT race
# Adding attribute capital-loss
# Adding attribute workclass
# Adding attribute sex
# Adding attribute occupation
# Adding attribute fnlwgt
# Adding attribute native-country
# Adding attribute capital-gain
# Adding attribute education-num
# Adding attribute relationship
# Adding attribute hours-per-week
# Adding attribute age
# Adding attribute marital-status
# Adding attribute income>50K
# ========================== BN constructed ==========================
# [429.6108990959983, 439.370820418997, 420.668604759001, 447.3623400539982, 406.90775563499847, 441.50370269700215, 401.63011164899945, 425.3974930160002, 429.35896689400033, 432.0278655840011]

# %% [markdown]
# ### Step 5 compare the statistics of input and sythetic data (optional)
#
# The synthetic data is already saved in a file by step 4. The ModelInspector is for a quick test on the similarity between input and synthetic datasets.
#
# #### 5.1 instantiate a ModelInspector.
#
# It needs input dataset, synthetic dataset, and attribute description.

# %%
# Read both datasets using Pandas.
#use below line for comparing to original dataset
#input_df = pd.read_csv(input_data, skipinitialspace=True)
#use below line for comparing to fair dataset
fair_df = pd.read_csv(sythetic_data_fair)
synthetic_df = pd.read_csv(synthetic_data)
# Read attribute description from the dataset description file.
attribute_description = read_json_file(description_file)['attribute_description']

inspector = ModelInspector(fair_df, synthetic_df, attribute_description)

# %% [markdown]
# #### 5.2 compare histograms between input and synthetic datasets.

# %%
for attribute in synthetic_df.columns:
    inspector.compare_histograms(attribute)

# %% [markdown]
# #### 5.3 compare pairwise mutual information

# %%
inspector.mutual_information_heatmap()
